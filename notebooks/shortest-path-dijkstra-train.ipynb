# %% [markdown]
# # Fixed-Size Shortest Paths / Dijkstra
#
# Эксперимент `shortest_path_dijkstra/`: фиксированный weighted graph, output фиксированной длины `dist[0..N-1]`, auxiliary loss на внутреннее состояние алгоритма Дейкстры (`dist[]`, `visited[]`) на output-позициях.

# %% [markdown]
# ## 0. Setup

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
personal_token = user_secrets.get_secret("GITHUB_TOKEN")

# !rm -rf transformer-analyzing
# !git clone https://{personal_token}@github.com/maximvw/transformer-analyzing.git transformer-analyzing
# %cd transformer-analyzing


import sys
from pathlib import Path
import json
import torch

print("Python:", sys.executable)
PYTHON = sys.executable
print("CUDA available:", torch.cuda.is_available())
print("CUDA devices:", torch.cuda.device_count())
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"GPU {i}: {props.name} | {props.total_memory / 1e9:.1f} GB")

ROOT = Path.cwd()
# Out:
# Cloning into 'transformer-analyzing'...
# remote: Enumerating objects: 561, done.
# remote: Counting objects: 100% (223/223), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 561 (delta 85), reused 164 (delta 48), pack-reused 338 (from 1)
# Receiving objects: 100% (561/561), 17.71 MiB | 35.01 MiB/s, done.
# Resolving deltas: 100% (232/232), done.
# /kaggle/working/transformer-analyzing
# Python: /usr/bin/python3
# CUDA available: True
# CUDA devices: 2
# GPU 0: Tesla T4 | 15.6 GB
# GPU 1: Tesla T4 | 15.6 GB

# %% [markdown]
# ## 1. Конфиг
#
# Сверху есть переключатель `CONFIG_MODE`: `"smoke"` для быстрой проверки, что тетрадка запускается, и `"full"` для основного эксперимента.

# %%
CONFIG_MODE = "full"  # "smoke" | "full"

SMOKE_CONFIG = {
    "graph_n": 6,
    "max_weight": 5,
    "max_distance": 40,
    "max_seq_len": 64,
    "n_train": 256,
    "n_val": 64,
    "n_test": 64,
    "d_model": 16,
    "n_head": 4,
    "batch_size": 32,
    "epochs": 2,
    "patience": 1,
    "lr": 1e-4,
    "aux_lambdas": [0.1, 1.0, 10.0],
    "sft_layers": [2, 4, 6],
    "aux_layers": [2, 4, 6],
}

FULL_CONFIG = {
    "graph_n": 10,
    "max_weight": 9,
    "max_distance": 99,
    "max_seq_len": 128,
    "n_train": 80000,
    "n_val": 2000,
    "n_test": 2000,
    "d_model": 128,
    "n_head": 4,
    "batch_size": 128,
    "epochs": 50,
    "patience": 8,
    "lr": 1e-4,
    "aux_lambdas": [0.1, 1.0, 10.0],
    "sft_layers": [2, 4, 6],
    "aux_layers": [2, 4, 6],
}

CONFIGS = {
    "smoke": SMOKE_CONFIG,
    "full": FULL_CONFIG,
}
assert CONFIG_MODE in CONFIGS, f"Unknown CONFIG_MODE: {CONFIG_MODE}"
CFG = CONFIGS[CONFIG_MODE]

GRAPH_N = CFG["graph_n"]
MAX_WEIGHT = CFG["max_weight"]
MAX_DISTANCE = CFG["max_distance"]
MAX_SEQ_LEN = CFG["max_seq_len"]
N_TRAIN = CFG["n_train"]
N_VAL = CFG["n_val"]
N_TEST = CFG["n_test"]
D_MODEL = CFG["d_model"]
N_HEAD = CFG["n_head"]
BATCH_SIZE = CFG["batch_size"]
EPOCHS = CFG["epochs"]
PATIENCE = CFG["patience"]
LR = CFG["lr"]
AUX_LAMBDAS = CFG["aux_lambdas"]
SFT_LAYERS = CFG["sft_layers"]
AUX_LAYERS = CFG["aux_layers"]

RUN_TAG = f"{CONFIG_MODE}_n{GRAPH_N}"
DATA_DIR = ROOT / "shortest_path_dijkstra" / f"data_{RUN_TAG}"
CKPT_DIR = ROOT / "checkpoints" / f"shortest_path_dijkstra_{RUN_TAG}"
DATA_DIR.mkdir(parents=True, exist_ok=True)
CKPT_DIR.mkdir(parents=True, exist_ok=True)

print(f"CONFIG_MODE={CONFIG_MODE}")
print(json.dumps(CFG, indent=2))
print("DATA_DIR:", DATA_DIR)
print("CKPT_DIR:", CKPT_DIR)
# Out:
# CONFIG_MODE=full
# {
#   "graph_n": 10,
#   "max_weight": 9,
#   "max_distance": 99,
#   "max_seq_len": 128,
#   "n_train": 80000,
#   "n_val": 2000,
#   "n_test": 2000,
#   "d_model": 128,
#   "n_head": 4,
#   "batch_size": 128,
#   "epochs": 50,
#   "patience": 8,
#   "lr": 0.0001,
#   "aux_lambdas": [
#     0.1,
#     1.0,
#     10.0
#   ],
#   "sft_layers": [
#     2,
#     4,
#     6
#   ]
# }
# DATA_DIR: /kaggle/working/transformer-analyzing/shortest_path_dijkstra/data_full_n10
# CKPT_DIR: /kaggle/working/transformer-analyzing/checkpoints/shortest_path_dijkstra_full_n10

# %% [markdown]
# ## 2. Генерация данных

# %%
# !$PYTHON -m shortest_path_dijkstra.scripts.generate_data \
    --output_dir "$DATA_DIR" \
    --n_train $N_TRAIN \
    --n_val $N_VAL \
    --n_test $N_TEST \
    --graph_n $GRAPH_N \
    --edge_prob 0.25 \
    --dense_edge_prob 0.55 \
    --max_weight $MAX_WEIGHT \
    --max_distance $MAX_DISTANCE \
    --seed 42

for path in sorted(DATA_DIR.glob("*.json")):
    with open(path) as f:
        items = json.load(f)
    print(f"{path.name}: {len(items)} examples")
    if items:
        ex = items[0]
        print(" N:", ex["n"], "edges:", ex["num_edges"], "type:", ex["split_type"])
        print(" source:", ex["source"])
        print(" first row:", ex["matrix"][0])
        print(" distances:", ex["distances"])
        print(" first dist states:", ex["dist_states"][:2])
# Out:
# train: n=80000 | graph_N=10 | avg_edges=29.26 max_dist=56 | types={'random': 80000}
# val: n=2000 | graph_N=10 | avg_edges=29.11 max_dist=43 | types={'random': 2000}
# test_id: n=2000 | graph_N=10 | avg_edges=29.16 max_dist=52 | types={'random': 2000}
# test_ood_dense: n=2000 | graph_N=10 | avg_edges=53.79 max_dist=20 | types={'dense': 2000}
# test_ood_long_chain: n=2000 | graph_N=10 | avg_edges=14.07 max_dist=18 | types={'long_chain': 2000}
# test_ood_adversarial_direct: n=2000 | graph_N=10 | avg_edges=20.45 max_dist=9 | types={'adversarial_direct': 2000}
# test_ood_equal_ties: n=2000 | graph_N=10 | avg_edges=24.12 max_dist=18 | types={'equal_ties': 2000}
# test_ood_layered_bipartite: n=2000 | graph_N=10 | avg_edges=25.83 max_dist=10 | types={'layered_bipartite': 2000}
# test_ood_near_complete_hidden_path: n=2000 | graph_N=10 | avg_edges=90.00 max_dist=9 | types={'near_complete_hidden_path': 2000}
# test_id.json: 2000 examples
#  N: 10 edges: 30 type: random
#  source: 0
#  first row: [0, None, None, 1, 4, 8, None, 2, None, None]
#  distances: [0, 3, 7, 1, 4, 6, 10, 2, 6, 8]
#  first dist states: [[0, 99, 99, 1, 4, 8, 99, 2, 99, 99], [0, 3, 99, 1, 4, 6, 99, 2, 99, 99]]
# test_ood_adversarial_direct.json: 2000 examples
#  N: 10 edges: 22 type: adversarial_direct
#  source: 0
#  first row: [0, 9, 7, 9, 5, 8, 1, 9, 5, 9]
#  distances: [0, 6, 4, 5, 3, 5, 1, 4, 2, 6]
#  first dist states: [[0, 9, 7, 9, 5, 8, 1, 9, 5, 9], [0, 9, 7, 9, 5, 8, 1, 4, 2, 9]]
# test_ood_dense.json: 2000 examples
#  N: 10 edges: 48 type: dense
#  source: 0
#  first row: [0, 9, None, None, 9, 5, None, 8, None, None]
#  distances: [0, 9, 13, 9, 9, 5, 11, 8, 11, 11]
#  first dist states: [[0, 9, 99, 99, 9, 5, 99, 8, 99, 99], [0, 9, 99, 99, 9, 5, 99, 8, 99, 11]]
# test_ood_equal_ties.json: 2000 examples
#  N: 10 edges: 24 type: equal_ties
#  source: 0
#  first row: [0, 2, 2, 2, 2, None, None, 5, None, None]
#  distances: [0, 2, 2, 2, 2, 4, 4, 4, 4, 4]
#  first dist states: [[0, 2, 2, 2, 2, 99, 99, 5, 99, 99], [0, 2, 2, 2, 2, 99, 4, 4, 4, 99]]
# test_ood_layered_bipartite.json: 2000 examples
#  N: 10 edges: 27 type: layered_bipartite
#  source: 0
#  first row: [0, None, 7, 9, 9, 9, None, 1, 7, 9]
#  distances: [0, 10, 7, 9, 9, 8, 9, 1, 7, 2]
#  first dist states: [[0, 99, 7, 9, 9, 9, 99, 1, 7, 9], [0, 10, 7, 9, 9, 9, 9, 1, 7, 2]]
# test_ood_long_chain.json: 2000 examples
#  N: 10 edges: 15 type: long_chain
#  source: 0
#  first row: [0, None, None, None, None, None, 8, None, None, 1]
#  distances: [0, 3, 13, 9, 6, 13, 7, 12, 10, 1]
#  first dist states: [[0, 99, 99, 99, 99, 99, 8, 99, 99, 1], [0, 3, 99, 99, 99, 99, 8, 99, 10, 1]]
# test_ood_near_complete_hidden_path.json: 2000 examples
#  N: 10 edges: 90 type: near_complete_hidden_path
#  source: 0
#  first row: [0, 9, 7, 9, 5, 8, 1, 7, 7, 6]
#  distances: [0, 8, 5, 6, 2, 8, 1, 4, 7, 3]
#  first dist states: [[0, 9, 7, 9, 5, 8, 1, 7, 7, 6], [0, 8, 7, 9, 2, 8, 1, 7, 7, 6]]
# train.json: 80000 examples
#  N: 10 edges: 29 type: random
#  source: 0
#  first row: [0, 9, None, 7, None, None, None, None, 7, None]
#  distances: [0, 9, 8, 7, 10, 9, 12, 11, 7, 12]
#  first dist states: [[0, 9, 99, 7, 99, 99, 99, 99, 7, 99], [0, 9, 8, 7, 99, 99, 99, 99, 7, 12]]
# val.json: 2000 examples
#  N: 10 edges: 30 type: random
#  source: 0
#  first row: [0, None, 8, None, 5, None, None, None, 6, 2]
#  distances: [0, 4, 8, 7, 5, 6, 9, 10, 3, 2]
#  first dist states: [[0, 99, 8, 99, 5, 99, 99, 99, 6, 2], [0, 99, 8, 7, 5, 6, 99, 99, 3, 2]]

# %% [markdown]
# ## 3. SFT depth ablation

# %%
for n_layer in SFT_LAYERS:
    print(f"{'=' * 70}")
    print(f"Training Shortest Path SFT {n_layer}L")
    print(f"{'=' * 70}")
    SAVE_DIR = CKPT_DIR / f"dijkstra_sft_{n_layer}L"
    !"$PYTHON" -m shortest_path_dijkstra.src.train \
        --train_path "{DATA_DIR / 'train.json'}" \
        --val_path "{DATA_DIR / 'val.json'}" \
        --graph_n {GRAPH_N} \
        --max_weight {MAX_WEIGHT} \
        --max_distance {MAX_DISTANCE} \
        --d_model {D_MODEL} --n_layer {n_layer} --n_head {N_HEAD} \
        --max_seq_len {MAX_SEQ_LEN} \
        --lr {LR} --weight_decay 0.01 \
        --batch_size {BATCH_SIZE} --epochs {EPOCHS} --patience {PATIENCE} \
        --lambda_state 0.0 \
        --num_workers 2 \
        --save_dir "{SAVE_DIR}" \
        --seed 42
# Out:
# ======================================================================
# Training Shortest Path SFT 2L
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 429,440
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=2.3174 tok_acc=0.3840 | val loss=1.7247 tok_acc=0.4815
# Epoch   1 | train loss=1.6237 tok_acc=0.4883 | val loss=1.5774 tok_acc=0.4893
# Epoch   2 | train loss=1.5397 tok_acc=0.4935 | val loss=1.5037 tok_acc=0.4990
# Epoch   3 | train loss=1.4301 tok_acc=0.5130 | val loss=1.3376 tok_acc=0.5362
# Epoch   4 | train loss=1.2462 tok_acc=0.5710 | val loss=1.1570 tok_acc=0.6069
# Epoch   5 | train loss=1.0872 tok_acc=0.6321 | val loss=1.0040 tok_acc=0.6611
# Epoch   6 | train loss=0.9469 tok_acc=0.6835 | val loss=0.8959 tok_acc=0.7006
# Epoch   7 | train loss=0.8632 tok_acc=0.7133 | val loss=0.8313 tok_acc=0.7220
# Epoch   8 | train loss=0.8116 tok_acc=0.7294 | val loss=0.7888 tok_acc=0.7354
# Epoch   9 | train loss=0.7731 tok_acc=0.7401 | val loss=0.7555 tok_acc=0.7444
# Epoch  10 | train loss=0.7368 tok_acc=0.7504 | val loss=0.7165 tok_acc=0.7532
# Epoch  11 | train loss=0.7031 tok_acc=0.7595 | val loss=0.6833 tok_acc=0.7668
# Epoch  12 | train loss=0.6566 tok_acc=0.7732 | val loss=0.6263 tok_acc=0.7825
# Epoch  13 | train loss=0.6067 tok_acc=0.7905 | val loss=0.5817 tok_acc=0.8009
# Epoch  14 | train loss=0.5487 tok_acc=0.8112 | val loss=0.5110 tok_acc=0.8265
# Epoch  15 | train loss=0.4823 tok_acc=0.8353 | val loss=0.4506 tok_acc=0.8478
# Epoch  16 | train loss=0.4193 tok_acc=0.8575 | val loss=0.3919 tok_acc=0.8685
# Epoch  17 | train loss=0.3723 tok_acc=0.8749 | val loss=0.3527 tok_acc=0.8840
# Epoch  18 | train loss=0.3409 tok_acc=0.8859 | val loss=0.3328 tok_acc=0.8875
# Epoch  19 | train loss=0.3253 tok_acc=0.8909 | val loss=0.3225 tok_acc=0.8921
# Epoch  41 | train loss=0.0745 tok_acc=0.9731 | val loss=0.1103 tok_acc=0.9645
# Epoch  42 | train loss=0.0721 tok_acc=0.9738 | val loss=0.1090 tok_acc=0.9648
# Epoch  43 | train loss=0.0699 tok_acc=0.9747 | val loss=0.1065 tok_acc=0.9643
# Epoch  44 | train loss=0.0684 tok_acc=0.9752 | val loss=0.1077 tok_acc=0.9641
# Epoch  45 | train loss=0.0664 tok_acc=0.9759 | val loss=0.1071 tok_acc=0.9652
# Epoch  46 | train loss=0.0643 tok_acc=0.9767 | val loss=0.1098 tok_acc=0.9640
# Epoch  47 | train loss=0.0622 tok_acc=0.9774 | val loss=0.1099 tok_acc=0.9640
# Epoch  48 | train loss=0.0605 tok_acc=0.9781 | val loss=0.1141 tok_acc=0.9642
# Epoch  49 | train loss=0.0584 tok_acc=0.9791 | val loss=0.1096 tok_acc=0.9651
# Training complete. Best val loss: 0.1065

# %% [markdown]
# ## 4. Auxiliary Loss Across Depths

# %%
for n_layer in AUX_LAYERS:
    for aux_lambda in AUX_LAMBDAS:
        print(f"{'=' * 70}")
        print(f"Training Shortest Path {n_layer}L + Aux (lambda={aux_lambda})")
        print(f"{'=' * 70}")
        SAVE_DIR = CKPT_DIR / f"dijkstra_aux_{n_layer}L_lambda{aux_lambda}"
        !"$PYTHON" -m shortest_path_dijkstra.src.train \
            --train_path "{DATA_DIR / 'train.json'}" \
            --val_path "{DATA_DIR / 'val.json'}" \
            --graph_n {GRAPH_N} \
            --max_weight {MAX_WEIGHT} \
            --max_distance {MAX_DISTANCE} \
            --d_model {D_MODEL} --n_layer {n_layer} --n_head {N_HEAD} \
            --max_seq_len {MAX_SEQ_LEN} \
            --lr {LR} --weight_decay 0.01 \
            --batch_size {BATCH_SIZE} --epochs {EPOCHS} --patience {PATIENCE} \
            --lambda_state {aux_lambda} \
            --num_workers 2 \
            --save_dir "{SAVE_DIR}" \
            --seed 42
# Out:
# ======================================================================
# Training Shortest Path 2L + Aux (lambda=0.1)
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 429,440
# Probe parameters: 134,640
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=2.9097 tok_acc=0.2986 | val loss=2.4252 tok_acc=0.3965
# Epoch   1 | train loss=2.1067 tok_acc=0.4644 | val loss=1.9639 tok_acc=0.4786
# Epoch   2 | train loss=1.8863 tok_acc=0.4898 | val loss=1.8537 tok_acc=0.4913
# Epoch   3 | train loss=1.7954 tok_acc=0.4986 | val loss=1.7392 tok_acc=0.5044
# Epoch   4 | train loss=1.6769 tok_acc=0.5206 | val loss=1.6157 tok_acc=0.5356
# Epoch   5 | train loss=1.5645 tok_acc=0.5562 | val loss=1.5128 tok_acc=0.5780
# Epoch   6 | train loss=1.4688 tok_acc=0.5919 | val loss=1.4264 tok_acc=0.6048
# Epoch   7 | train loss=1.4076 tok_acc=0.6121 | val loss=1.3780 tok_acc=0.6222
# Epoch   8 | train loss=1.3556 tok_acc=0.6294 | val loss=1.3372 tok_acc=0.6357
# Epoch  40 | train loss=0.7442 tok_acc=0.8274 | val loss=0.7721 tok_acc=0.8166
# Epoch  41 | train loss=0.7357 tok_acc=0.8297 | val loss=0.7627 tok_acc=0.8193
# Epoch  42 | train loss=0.7270 tok_acc=0.8323 | val loss=0.7545 tok_acc=0.8211
# Epoch  43 | train loss=0.7198 tok_acc=0.8345 | val loss=0.7466 tok_acc=0.8255
# Epoch  44 | train loss=0.7122 tok_acc=0.8367 | val loss=0.7419 tok_acc=0.8251
# Epoch  45 | train loss=0.7048 tok_acc=0.8390 | val loss=0.7323 tok_acc=0.8281
# Epoch  46 | train loss=0.6982 tok_acc=0.8409 | val loss=0.7291 tok_acc=0.8293
# Epoch  47 | train loss=0.6914 tok_acc=0.8428 | val loss=0.7238 tok_acc=0.8290
# Epoch  48 | train loss=0.6832 tok_acc=0.8452 | val loss=0.7185 tok_acc=0.8314
# Epoch  49 | train loss=0.6763 tok_acc=0.8471 | val loss=0.7133 tok_acc=0.8350
# Training complete. Best val loss: 0.7133
# ======================================================================
# Training Shortest Path 2L + Aux (lambda=1.0)
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 429,440
# Probe parameters: 134,640
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=6.0806 tok_acc=0.3137 | val loss=4.8629 tok_acc=0.4751
# Epoch   1 | train loss=4.5729 tok_acc=0.4850 | val loss=4.3795 tok_acc=0.4898
# Epoch   2 | train loss=4.2652 tok_acc=0.4995 | val loss=4.1725 tok_acc=0.5080
# Epoch   3 | train loss=4.1086 tok_acc=0.5152 | val loss=4.0453 tok_acc=0.5195
# Epoch   4 | train loss=3.9844 tok_acc=0.5310 | val loss=3.9219 tok_acc=0.5349
# Epoch   5 | train loss=3.8565 tok_acc=0.5452 | val loss=3.7923 tok_acc=0.5522
# Epoch   6 | train loss=3.7215 tok_acc=0.5634 | val loss=3.6452 tok_acc=0.5767
# Epoch   7 | train loss=3.5692 tok_acc=0.5890 | val loss=3.4810 tok_acc=0.6055
# Epoch   8 | train loss=3.3988 tok_acc=0.6147 | val loss=3.3093 tok_acc=0.6254
# Epoch   9 | train loss=3.2190 tok_acc=0.6443 | val loss=3.1338 tok_acc=0.6570
# Epoch  10 | train loss=3.0614 tok_acc=0.6696 | val loss=2.9941 tok_acc=0.6800
# Epoch  11 | train loss=2.9336 tok_acc=0.6869 | val loss=2.8736 tok_acc=0.6944
# Epoch  12 | train loss=2.8175 tok_acc=0.7005 | val loss=2.7921 tok_acc=0.7003
# Epoch  13 | train loss=2.7195 tok_acc=0.7124 | val loss=2.6807 tok_acc=0.7176
# Epoch  14 | train loss=2.6383 tok_acc=0.7199 | val loss=2.6117 tok_acc=0.7175
# Epoch  15 | train loss=2.5661 tok_acc=0.7277 | val loss=2.5588 tok_acc=0.7242
# Epoch  16 | train loss=2.5010 tok_acc=0.7338 | val loss=2.4629 tok_acc=0.7412
# Epoch  17 | train loss=2.4430 tok_acc=0.7394 | val loss=2.4218 tok_acc=0.7404
# Epoch  18 | train loss=2.3922 tok_acc=0.7436 | val loss=2.3762 tok_acc=0.7420
# Epoch  19 | train loss=2.3452 tok_acc=0.7475 | val loss=2.3289 tok_acc=0.7479
# Epoch  20 | train loss=2.3041 tok_acc=0.7516 | val loss=2.2856 tok_acc=0.7530
# Epoch  21 | train loss=2.2648 tok_acc=0.7554 | val loss=2.2532 tok_acc=0.7544
# Epoch  22 | train loss=2.2285 tok_acc=0.7587 | val loss=2.2210 tok_acc=0.7594
# Epoch  23 | train loss=2.1954 tok_acc=0.7622 | val loss=2.1897 tok_acc=0.7597
# Epoch  24 | train loss=2.1663 tok_acc=0.7652 | val loss=2.1752 tok_acc=0.7583
# Epoch  25 | train loss=2.1389 tok_acc=0.7676 | val loss=2.1411 tok_acc=0.7645
# Epoch  26 | train loss=2.1152 tok_acc=0.7697 | val loss=2.1088 tok_acc=0.7690
# Epoch  27 | train loss=2.0916 tok_acc=0.7732 | val loss=2.1042 tok_acc=0.7662
# Epoch  28 | train loss=2.0710 tok_acc=0.7753 | val loss=2.0766 tok_acc=0.7725
# Epoch  29 | train loss=2.0519 tok_acc=0.7773 | val loss=2.0601 tok_acc=0.7740
# Epoch  30 | train loss=2.0325 tok_acc=0.7797 | val loss=2.0357 tok_acc=0.7748
# Epoch  31 | train loss=2.0149 tok_acc=0.7813 | val loss=2.0203 tok_acc=0.7753
# Epoch  32 | train loss=1.9986 tok_acc=0.7837 | val loss=1.9975 tok_acc=0.7846
# Epoch  33 | train loss=1.9838 tok_acc=0.7853 | val loss=1.9928 tok_acc=0.7789
# Epoch  34 | train loss=1.9689 tok_acc=0.7868 | val loss=1.9751 tok_acc=0.7825
# Epoch  35 | train loss=1.9549 tok_acc=0.7884 | val loss=1.9645 tok_acc=0.7840
# Epoch  36 | train loss=1.9394 tok_acc=0.7909 | val loss=1.9582 tok_acc=0.7827
# Epoch  37 | train loss=1.9259 tok_acc=0.7921 | val loss=1.9353 tok_acc=0.7875
# Epoch  38 | train loss=1.9138 tok_acc=0.7934 | val loss=1.9202 tok_acc=0.7915
# Epoch  39 | train loss=1.9014 tok_acc=0.7948 | val loss=1.9097 tok_acc=0.7906
# Epoch  40 | train loss=1.8902 tok_acc=0.7961 | val loss=1.9112 tok_acc=0.7900
# Epoch  41 | train loss=1.8777 tok_acc=0.7981 | val loss=1.9027 tok_acc=0.7878
# Epoch  42 | train loss=1.8667 tok_acc=0.7998 | val loss=1.8973 tok_acc=0.7892
# Epoch  43 | train loss=1.8561 tok_acc=0.8014 | val loss=1.8641 tok_acc=0.7958
# Epoch  44 | train loss=1.8476 tok_acc=0.8018 | val loss=1.8608 tok_acc=0.7960
# Epoch  45 | train loss=1.8364 tok_acc=0.8040 | val loss=1.8619 tok_acc=0.7924
# Epoch  46 | train loss=1.8284 tok_acc=0.8044 | val loss=1.8415 tok_acc=0.7989
# Epoch  47 | train loss=1.8185 tok_acc=0.8056 | val loss=1.8455 tok_acc=0.7925
# Epoch  48 | train loss=1.8088 tok_acc=0.8071 | val loss=1.8303 tok_acc=0.8016
# Epoch  49 | train loss=1.8002 tok_acc=0.8085 | val loss=1.8282 tok_acc=0.7955
# Training complete. Best val loss: 1.8282
# ======================================================================
# Training Shortest Path 2L + Aux (lambda=10.0)
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 429,440
# Probe parameters: 134,640
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=37.0297 tok_acc=0.2606 | val loss=29.9467 tok_acc=0.2935
# Epoch   1 | train loss=29.2078 tok_acc=0.3813 | val loss=28.4903 tok_acc=0.4198
# Epoch   2 | train loss=27.7420 tok_acc=0.4634 | val loss=26.9775 tok_acc=0.4748
# Epoch   3 | train loss=26.2777 tok_acc=0.4815 | val loss=25.4987 tok_acc=0.4775
# Epoch   4 | train loss=24.7484 tok_acc=0.4878 | val loss=23.9546 tok_acc=0.4857
# Epoch   5 | train loss=23.1940 tok_acc=0.4911 | val loss=22.4692 tok_acc=0.4872
# Epoch   6 | train loss=21.7678 tok_acc=0.4937 | val loss=21.0859 tok_acc=0.4890
# Epoch   7 | train loss=20.4648 tok_acc=0.4955 | val loss=19.8370 tok_acc=0.4955
# Epoch   8 | train loss=19.2701 tok_acc=0.4969 | val loss=18.7240 tok_acc=0.4923
# Epoch   9 | train loss=18.2517 tok_acc=0.4982 | val loss=17.8089 tok_acc=0.4938
# Epoch  10 | train loss=17.3843 tok_acc=0.5000 | val loss=17.0348 tok_acc=0.4989
# Epoch  11 | train loss=16.6623 tok_acc=0.5041 | val loss=16.3760 tok_acc=0.5037
# Epoch  12 | train loss=16.0699 tok_acc=0.5074 | val loss=15.8412 tok_acc=0.5071
# Epoch  13 | train loss=15.5737 tok_acc=0.5126 | val loss=15.3890 tok_acc=0.5105
# Epoch  14 | train loss=15.1508 tok_acc=0.5170 | val loss=15.0297 tok_acc=0.5130
# Epoch  15 | train loss=14.7899 tok_acc=0.5223 | val loss=14.6956 tok_acc=0.5200
# Epoch  16 | train loss=14.4591 tok_acc=0.5259 | val loss=14.3673 tok_acc=0.5243
# Epoch  17 | train loss=14.1655 tok_acc=0.5300 | val loss=14.0920 tok_acc=0.5275
# Epoch  18 | train loss=13.9097 tok_acc=0.5336 | val loss=13.8631 tok_acc=0.5288
# Epoch  19 | train loss=13.6712 tok_acc=0.5371 | val loss=13.6437 tok_acc=0.5340
# Epoch  20 | train loss=13.4591 tok_acc=0.5398 | val loss=13.4392 tok_acc=0.5357
# Epoch  21 | train loss=13.2592 tok_acc=0.5426 | val loss=13.2635 tok_acc=0.5438
# Epoch  22 | train loss=13.0691 tok_acc=0.5452 | val loss=13.0558 tok_acc=0.5411
# Epoch  23 | train loss=12.8881 tok_acc=0.5487 | val loss=12.8982 tok_acc=0.5459
# Epoch  24 | train loss=12.7103 tok_acc=0.5517 | val loss=12.7101 tok_acc=0.5482
# Epoch  25 | train loss=12.5390 tok_acc=0.5529 | val loss=12.5627 tok_acc=0.5415
# Epoch  26 | train loss=12.3817 tok_acc=0.5565 | val loss=12.4004 tok_acc=0.5561
# Epoch  27 | train loss=12.2134 tok_acc=0.5586 | val loss=12.2347 tok_acc=0.5590
# Epoch  28 | train loss=12.0484 tok_acc=0.5613 | val loss=12.0868 tok_acc=0.5519
# Epoch  29 | train loss=11.8971 tok_acc=0.5645 | val loss=11.9334 tok_acc=0.5554
# Epoch  30 | train loss=11.7578 tok_acc=0.5667 | val loss=11.7961 tok_acc=0.5631
# Epoch  31 | train loss=11.6188 tok_acc=0.5697 | val loss=11.6850 tok_acc=0.5572
# Epoch  32 | train loss=11.4908 tok_acc=0.5719 | val loss=11.5188 tok_acc=0.5662
# Epoch  33 | train loss=11.3373 tok_acc=0.5742 | val loss=11.3800 tok_acc=0.5647
# Epoch  34 | train loss=11.1910 tok_acc=0.5755 | val loss=11.2318 tok_acc=0.5715
# Epoch  35 | train loss=11.0590 tok_acc=0.5789 | val loss=11.1055 tok_acc=0.5680
# Epoch  36 | train loss=10.9303 tok_acc=0.5806 | val loss=10.9654 tok_acc=0.5741
# Epoch  37 | train loss=10.8102 tok_acc=0.5827 | val loss=10.8923 tok_acc=0.5731
# Epoch  38 | train loss=10.6858 tok_acc=0.5855 | val loss=10.7438 tok_acc=0.5773
# Epoch  39 | train loss=10.5721 tok_acc=0.5882 | val loss=10.6075 tok_acc=0.5771
# Epoch  40 | train loss=10.4507 tok_acc=0.5915 | val loss=10.4868 tok_acc=0.5814
# Epoch  41 | train loss=10.3426 tok_acc=0.5939 | val loss=10.4331 tok_acc=0.5814
# Epoch  42 | train loss=10.2346 tok_acc=0.5968 | val loss=10.2785 tok_acc=0.5892
# Epoch  43 | train loss=10.1389 tok_acc=0.5989 | val loss=10.2104 tok_acc=0.5885
# Epoch  44 | train loss=10.0407 tok_acc=0.6017 | val loss=10.1057 tok_acc=0.5953
# Epoch  45 | train loss=9.9499 tok_acc=0.6045 | val loss=10.0064 tok_acc=0.5976
# Epoch  46 | train loss=9.8624 tok_acc=0.6072 | val loss=9.9480 tok_acc=0.5996
# Epoch  47 | train loss=9.7819 tok_acc=0.6088 | val loss=9.8722 tok_acc=0.6000
# Epoch  48 | train loss=9.7007 tok_acc=0.6115 | val loss=9.7790 tok_acc=0.6046
# Epoch  49 | train loss=9.6199 tok_acc=0.6133 | val loss=9.7427 tok_acc=0.6022
# Training complete. Best val loss: 9.7427

# %% [markdown]
# ## 5. Продолжение обучения с чекпоинта
#
# В каждом `SAVE_DIR` хранится только один лучший чекпоинт: `checkpoint_best.pt`. При новом улучшении он перезаписывается, поэтому на Kaggle не копятся десятки моделей.

# %%
# # Продолжить SFT 2L:
# n_layer = 2
# SAVE_DIR = CKPT_DIR / f"dijkstra_sft_{n_layer}L"
# RESUME_FROM = SAVE_DIR / "checkpoint_best.pt"
# EPOCHS = 80
# !"$PYTHON" -m shortest_path_dijkstra.src.train \\
#     --train_path "{DATA_DIR / 'train.json'}" \\
#     --val_path "{DATA_DIR / 'val.json'}" \\
#     --graph_n {GRAPH_N} \\
#     --max_weight {MAX_WEIGHT} \\
#     --max_distance {MAX_DISTANCE} \\
#     --d_model {D_MODEL} --n_layer {n_layer} --n_head {N_HEAD} \\
#     --max_seq_len {MAX_SEQ_LEN} \\
#     --lr {LR} --weight_decay 0.01 \\
#     --batch_size {BATCH_SIZE} --epochs {EPOCHS} --patience {PATIENCE} \\
#     --lambda_state 0.0 \\
#     --num_workers 2 \\
#     --save_dir "{SAVE_DIR}" \\
#     --resume_from "{RESUME_FROM}" \\
#     --seed 42

# # Продолжить 2L + auxiliary loss:
# aux_lambda = 1.0
# SAVE_DIR = CKPT_DIR / f"dijkstra_aux_2L_lambda{aux_lambda}"
# RESUME_FROM = SAVE_DIR / "checkpoint_best.pt"
# EPOCHS = 80
# !"$PYTHON" -m shortest_path_dijkstra.src.train \\
#     --train_path "{DATA_DIR / 'train.json'}" \\
#     --val_path "{DATA_DIR / 'val.json'}" \\
#     --graph_n {GRAPH_N} \\
#     --max_weight {MAX_WEIGHT} \\
#     --max_distance {MAX_DISTANCE} \\
#     --d_model {D_MODEL} --n_layer 2 --n_head {N_HEAD} \\
#     --max_seq_len {MAX_SEQ_LEN} \\
#     --lr {LR} --weight_decay 0.01 \\
#     --batch_size {BATCH_SIZE} --epochs {EPOCHS} --patience {PATIENCE} \\
#     --lambda_state {aux_lambda} \\
#     --num_workers 2 \\
#     --save_dir "{SAVE_DIR}" \\
#     --resume_from "{RESUME_FROM}" \\
#     --seed 42

# %% [markdown]
# ## 6. Evaluation

# %%
from shortest_path_dijkstra.src.evaluate import evaluate_all

all_eval = {}

for n_layer in SFT_LAYERS:
    name = f"SFT {n_layer}L"
    print(f"\n{'=' * 70}")
    print(name)
    print(f"{'=' * 70}")
    all_eval[name] = evaluate_all(
        checkpoint_path=str(CKPT_DIR / f"dijkstra_sft_{n_layer}L" / "checkpoint_best.pt"),
        data_dir=str(DATA_DIR),
        batch_size=BATCH_SIZE,
        lambda_state=0.0,
        graph_n=GRAPH_N,
        max_weight=MAX_WEIGHT,
        max_distance=MAX_DISTANCE,
        d_model=D_MODEL,
        n_layer=n_layer,
        n_head=N_HEAD,
        max_seq_len=MAX_SEQ_LEN,
    )

for n_layer in AUX_LAYERS:
    for aux_lambda in AUX_LAMBDAS:
        name = f"{n_layer}L + Aux (lambda={aux_lambda})"
        print(f"\n{'=' * 70}")
        print(name)
        print(f"{'=' * 70}")
        all_eval[name] = evaluate_all(
            checkpoint_path=str(CKPT_DIR / f"dijkstra_aux_{n_layer}L_lambda{aux_lambda}" / "checkpoint_best.pt"),
            data_dir=str(DATA_DIR),
            batch_size=BATCH_SIZE,
            lambda_state=aux_lambda,
            graph_n=GRAPH_N,
            max_weight=MAX_WEIGHT,
            max_distance=MAX_DISTANCE,
            d_model=D_MODEL,
            n_layer=n_layer,
            n_head=N_HEAD,
            max_seq_len=MAX_SEQ_LEN,
        )
# Out:
# ======================================================================
# SFT 2L
# ======================================================================
# test_id: exact_match=0.5055 distance_acc=0.9058 token_acc=0.9269 ntp_loss=0.2215 state_loss=0.0000 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0140 distance_acc=0.6076 token_acc=0.7831 ntp_loss=0.7912 state_loss=0.0000 (n=2000)
# test_ood_dense: exact_match=0.6610 distance_acc=0.9527 token_acc=0.9615 ntp_loss=0.1069 state_loss=0.0000 (n=2000)
# test_ood_equal_ties: exact_match=0.9895 distance_acc=0.9990 token_acc=0.9990 ntp_loss=0.0085 state_loss=0.0000 (n=2000)
# test_ood_layered_bipartite: exact_match=0.8655 distance_acc=0.9860 token_acc=0.9873 ntp_loss=0.0387 state_loss=0.0000 (n=2000)
# test_ood_long_chain: exact_match=0.0575 distance_acc=0.6614 token_acc=0.7985 ntp_loss=0.6925 state_loss=0.0000 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0055 distance_acc=0.5533 token_acc=0.7574 ntp_loss=1.4712 state_loss=0.0000 (n=2000)
# ======================================================================
# SFT 4L
# ======================================================================
# test_id: exact_match=0.6720 distance_acc=0.9440 token_acc=0.9521 ntp_loss=0.1363 state_loss=0.0000 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0220 distance_acc=0.6129 token_acc=0.7055 ntp_loss=1.1446 state_loss=0.0000 (n=2000)
# test_ood_dense: exact_match=0.8375 distance_acc=0.9793 token_acc=0.9817 ntp_loss=0.0497 state_loss=0.0000 (n=2000)
# test_ood_equal_ties: exact_match=0.9995 distance_acc=1.0000 token_acc=1.0000 ntp_loss=0.0015 state_loss=0.0000 (n=2000)
# test_ood_layered_bipartite: exact_match=0.9895 distance_acc=0.9990 token_acc=0.9990 ntp_loss=0.0043 state_loss=0.0000 (n=2000)
# test_ood_long_chain: exact_match=0.1010 distance_acc=0.7158 token_acc=0.7900 ntp_loss=0.6678 state_loss=0.0000 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0035 distance_acc=0.5644 token_acc=0.6211 ntp_loss=1.4001 state_loss=0.0000 (n=2000)
# ======================================================================
# SFT 6L
# ======================================================================
# test_id: exact_match=0.7075 distance_acc=0.9516 token_acc=0.9611 ntp_loss=0.1148 state_loss=0.0000 (n=2000)
# test_ood_adversarial_direct: exact_match=0.1015 distance_acc=0.7433 token_acc=0.8437 ntp_loss=0.4696 state_loss=0.0000 (n=2000)
# test_ood_dense: exact_match=0.8620 distance_acc=0.9835 token_acc=0.9853 ntp_loss=0.0449 state_loss=0.0000 (n=2000)
# test_ood_equal_ties: exact_match=0.9755 distance_acc=0.9972 token_acc=0.9975 ntp_loss=0.0063 state_loss=0.0000 (n=2000)
# test_ood_layered_bipartite: exact_match=0.9725 distance_acc=0.9972 token_acc=0.9975 ntp_loss=0.0102 state_loss=0.0000 (n=2000)
# test_ood_long_chain: exact_match=0.1655 distance_acc=0.7537 token_acc=0.8500 ntp_loss=0.5245 state_loss=0.0000 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0385 distance_acc=0.7096 token_acc=0.7934 ntp_loss=0.6969 state_loss=0.0000 (n=2000)
# ======================================================================
# 2L + Aux (lambda=0.1)
# ======================================================================
# test_id: exact_match=0.1535 distance_acc=0.7889 token_acc=0.8256 ntp_loss=0.4895 state_loss=2.4914 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0015 distance_acc=0.4929 token_acc=0.6823 ntp_loss=0.9216 state_loss=2.6313 (n=2000)
# test_ood_dense: exact_match=0.3180 distance_acc=0.8767 token_acc=0.8936 ntp_loss=0.2757 state_loss=2.3748 (n=2000)
# test_ood_equal_ties: exact_match=0.8310 distance_acc=0.9816 token_acc=0.9835 ntp_loss=0.0504 state_loss=1.7480 (n=2000)
# test_ood_layered_bipartite: exact_match=0.5715 distance_acc=0.9494 token_acc=0.9536 ntp_loss=0.1313 state_loss=2.5049 (n=2000)
# test_ood_long_chain: exact_match=0.0115 distance_acc=0.5736 token_acc=0.7178 ntp_loss=0.9073 state_loss=2.4233 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0030 distance_acc=0.5609 token_acc=0.7144 ntp_loss=1.0534 state_loss=2.5417 (n=2000)
# ======================================================================
# 2L + Aux (lambda=1.0)
# ======================================================================
# test_id: exact_match=0.0935 distance_acc=0.7492 token_acc=0.7883 ntp_loss=0.5768 state_loss=1.2835 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0115 distance_acc=0.5537 token_acc=0.7311 ntp_loss=0.7045 state_loss=1.3463 (n=2000)
# test_ood_dense: exact_match=0.1865 distance_acc=0.8313 token_acc=0.8601 ntp_loss=0.3394 state_loss=1.1160 (n=2000)
# test_ood_equal_ties: exact_match=0.7325 distance_acc=0.9695 token_acc=0.9720 ntp_loss=0.0764 state_loss=0.8653 (n=2000)
# test_ood_layered_bipartite: exact_match=0.3075 distance_acc=0.9043 token_acc=0.9126 ntp_loss=0.2306 state_loss=1.3153 (n=2000)
# test_ood_long_chain: exact_match=0.0060 distance_acc=0.5416 token_acc=0.6684 ntp_loss=0.9996 state_loss=1.3798 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0020 distance_acc=0.5141 token_acc=0.6790 ntp_loss=1.4652 state_loss=2.7235 (n=2000)
# ======================================================================
# 2L + Aux (lambda=10.0)
# ======================================================================
# test_id: exact_match=0.0020 distance_acc=0.5529 token_acc=0.5993 ntp_loss=1.1085 state_loss=0.8705 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0000 distance_acc=0.4339 token_acc=0.5603 ntp_loss=1.1196 state_loss=0.9447 (n=2000)
# test_ood_dense: exact_match=0.0105 distance_acc=0.6585 token_acc=0.7008 ntp_loss=0.7345 state_loss=0.7776 (n=2000)
# test_ood_equal_ties: exact_match=0.0730 distance_acc=0.7910 token_acc=0.7884 ntp_loss=0.4451 state_loss=0.9399 (n=2000)
# test_ood_layered_bipartite: exact_match=0.0270 distance_acc=0.7549 token_acc=0.7752 ntp_loss=0.6801 state_loss=0.7989 (n=2000)
# test_ood_long_chain: exact_match=0.0000 distance_acc=0.4024 token_acc=0.4943 ntp_loss=1.4886 state_loss=1.0062 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0000 distance_acc=0.4637 token_acc=0.5753 ntp_loss=1.2064 state_loss=1.1269 (n=2000)

# %%
import pandas as pd

rows = []
for model_name, result in all_eval.items():
    for split, metrics in result.items():
        rows.append({
            "model": model_name,
            "split": split,
            "exact_match": metrics["exact_match"],
            "distance_accuracy": metrics["distance_accuracy"],
            "token_accuracy": metrics["token_accuracy"],
            "ntp_loss": metrics["loss_main"],
            "total_loss": metrics["loss"],
            "loss_state": metrics["loss_state"],
        })
df = pd.DataFrame(rows)
df
# Out:
#                      model                               split  exact_match  \
# 0                   SFT 2L                             test_id       0.5055
# 1                   SFT 2L         test_ood_adversarial_direct       0.0140
# 2                   SFT 2L                      test_ood_dense       0.6610
# 3                   SFT 2L                 test_ood_equal_ties       0.9895
# 4                   SFT 2L          test_ood_layered_bipartite       0.8655
# 5                   SFT 2L                 test_ood_long_chain       0.0575
# 6                   SFT 2L  test_ood_near_complete_hidden_path       0.0055
# 7                   SFT 4L                             test_id       0.6720
# 8                   SFT 4L         test_ood_adversarial_direct       0.0220
# 9                   SFT 4L                      test_ood_dense       0.8375
# 10                  SFT 4L                 test_ood_equal_ties       0.9995
# 11                  SFT 4L          test_ood_layered_bipartite       0.9895
# 12                  SFT 4L                 test_ood_long_chain       0.1010
# 13                  SFT 4L  test_ood_near_complete_hidden_path       0.0035
# 14                  SFT 6L                             test_id       0.7075
# 15                  SFT 6L         test_ood_adversarial_direct       0.1015
# 16                  SFT 6L                      test_ood_dense       0.8620
# 17                  SFT 6L                 test_ood_equal_ties       0.9755
# 18                  SFT 6L          test_ood_layered_bipartite       0.9725
# 19                  SFT 6L                 test_ood_long_chain       0.1655
# 20                  SFT 6L  test_ood_near_complete_hidden_path       0.0385
# 21   2L + Aux (lambda=0.1)                             test_id       0.1535
# 22   2L + Aux (lambda=0.1)         test_ood_adversarial_direct       0.0015
# 23   2L + Aux (lambda=0.1)                      test_ood_dense       0.3180
# 24   2L + Aux (lambda=0.1)                 test_ood_equal_ties       0.8310
# 25   2L + Aux (lambda=0.1)          test_ood_layered_bipartite       0.5715
# 26   2L + Aux (lambda=0.1)                 test_ood_long_chain       0.0115
# 27   2L + Aux (lambda=0.1)  test_ood_near_complete_hidden_path       0.0030
# 28   2L + Aux (lambda=1.0)                             test_id       0.0935
# 29   2L + Aux (lambda=1.0)         test_ood_adversarial_direct       0.0115
# 30   2L + Aux (lambda=1.0)                      test_ood_dense       0.1865
# 31   2L + Aux (lambda=1.0)                 test_ood_equal_ties       0.7325
# 32   2L + Aux (lambda=1.0)          test_ood_layered_bipartite       0.3075
# 33   2L + Aux (lambda=1.0)                 test_ood_long_chain       0.0060
# 34   2L + Aux (lambda=1.0)  test_ood_near_complete_hidden_path       0.0020
# 35  2L + Aux (lambda=10.0)                             test_id       0.0020
# 36  2L + Aux (lambda=10.0)         test_ood_adversarial_direct       0.0000
# 37  2L + Aux (lambda=10.0)                      test_ood_dense       0.0105
# 38  2L + Aux (lambda=10.0)                 test_ood_equal_ties       0.0730
# 39  2L + Aux (lambda=10.0)          test_ood_layered_bipartite       0.0270
# 40  2L + Aux (lambda=10.0)                 test_ood_long_chain       0.0000
# 41  2L + Aux (lambda=10.0)  test_ood_near_complete_hidden_path       0.0000
#
#     distance_accuracy  token_accuracy  ntp_loss  total_loss  loss_state
# 0             0.90575        0.926864  0.221455    0.221455    0.000000
# 1             0.60760        0.783136  0.791203    0.791203    0.000000
# 2             0.95275        0.961545  0.106937    0.106937    0.000000
# 3             0.99895        0.999045  0.008509    0.008509    0.000000
# 4             0.98600        0.987273  0.038669    0.038669    0.000000
# 5             0.66140        0.798455  0.692516    0.692516    0.000000
# 6             0.55330        0.757409  1.471248    1.471248    0.000000
# 7             0.94405        0.952091  0.136301    0.136301    0.000000
# 8             0.61285        0.705455  1.144640    1.144640    0.000000
# 9             0.97930        0.981682  0.049693    0.049693    0.000000
# 10            0.99995        0.999955  0.001520    0.001520    0.000000
# 11            0.99895        0.999045  0.004301    0.004301    0.000000
# 12            0.71580        0.789955  0.667752    0.667752    0.000000
# 13            0.56435        0.621091  1.400141    1.400141    0.000000
# 14            0.95165        0.961091  0.114835    0.114835    0.000000
# 15            0.74335        0.843727  0.469567    0.469567    0.000000
# 16            0.98345        0.985273  0.044950    0.044950    0.000000
# 17            0.99720        0.997500  0.006270    0.006270    0.000000
# 18            0.99720        0.997455  0.010186    0.010186    0.000000
# 19            0.75370        0.850000  0.524519    0.524519    0.000000
# 20            0.70960        0.793409  0.696855    0.696855    0.000000
# 21            0.78890        0.825591  0.489503    0.738644    2.491415
# 22            0.49290        0.682318  0.921599    1.184733    2.631345
# 23            0.87670        0.893636  0.275697    0.513177    2.374796
# 24            0.98155        0.983455  0.050417    0.225217    1.748009
# 25            0.94935        0.953636  0.131304    0.381793    2.504890
# 26            0.57355        0.717773  0.907273    1.149605    2.423324
# 27            0.56095        0.714409  1.053446    1.307612    2.541659
# 28            0.74920        0.788318  0.576848    1.860393    1.283545
# 29            0.55370        0.731136  0.704521    2.050800    1.346279
# 30            0.83125        0.860136  0.339365    1.455336    1.115971
# 31            0.96950        0.972045  0.076433    0.941724    0.865291
# 32            0.90435        0.912636  0.230552    1.545887    1.315335
# 33            0.54160        0.668409  0.999602    2.379354    1.379752
# 34            0.51405        0.679045  1.465218    4.188669    2.723450
# 35            0.55290        0.599273  1.108460    9.813612    0.870515
# 36            0.43385        0.560273  1.119643   10.566978    0.944734
# 37            0.65855        0.700773  0.734468    8.510880    0.777641
# 38            0.79100        0.788409  0.445129    9.844442    0.939931
# 39            0.75485        0.775182  0.680100    8.669344    0.798924
# 40            0.40240        0.494318  1.488603   11.550575    1.006197
# 41            0.46370        0.575273  1.206372   12.475571    1.126920

# %% [markdown]
# ## 7. Training curves

# %%
import matplotlib.pyplot as plt

def load_log(path):
    with open(path) as f:
        return json.load(f)

logs = {
    **{
        f"SFT {n_layer}L": load_log(CKPT_DIR / f"dijkstra_sft_{n_layer}L" / "train_log.json")
        for n_layer in SFT_LAYERS
    },
    **{
        f"{n_layer}L + Aux ({aux_lambda})": load_log(
            CKPT_DIR / f"dijkstra_aux_{n_layer}L_lambda{aux_lambda}" / "train_log.json"
        )
        for n_layer in AUX_LAYERS
        for aux_lambda in AUX_LAMBDAS
    },
}

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for label, log in logs.items():
    epochs = [row["epoch"] for row in log]
    axes[0].plot(epochs, [row["val"]["loss_main"] for row in log], label=label)
    axes[1].plot(epochs, [row["val"]["token_accuracy"] for row in log], label=label)
    if any(row["val"]["loss_state"] > 0 for row in log):
        axes[2].plot(epochs, [row["val"]["loss_state"] for row in log], label=label)

axes[0].set_title("Val NTP loss")
axes[1].set_title("Val token accuracy")
axes[1].set_ylim(0.0, 1.02)
axes[2].set_title("Val Dijkstra-state loss")
for ax in axes:
    ax.grid(True, alpha=0.3)
    ax.legend()
plt.tight_layout()

# %% [markdown]
# ## 8. Split Heatmaps
#
# Сразу две защитные картинки: exact match и distance-wise accuracy на всех fixed-size split'ах.

# %%
import seaborn as sns
import numpy as np

split_order = [
    "test_id",
    "test_ood_dense",
    "test_ood_long_chain",
    "test_ood_adversarial_direct",
    "test_ood_equal_ties",
    "test_ood_layered_bipartite",
    "test_ood_near_complete_hidden_path",
]
split_labels = {
    "test_id": "ID",
    "test_ood_dense": "Dense",
    "test_ood_long_chain": "Long chain",
    "test_ood_adversarial_direct": "Adv. direct",
    "test_ood_equal_ties": "Equal ties",
    "test_ood_layered_bipartite": "Layered bipartite",
    "test_ood_near_complete_hidden_path": "Hidden path",
}

exact_df = pd.DataFrame(
    {
        model_name: {
            split_labels[split]: all_eval[model_name][split]["exact_match"]
            for split in split_order
            if split in all_eval[model_name]
        }
        for model_name in all_eval
    }
).T
distance_df = pd.DataFrame(
    {
        model_name: {
            split_labels[split]: all_eval[model_name][split]["distance_accuracy"]
            for split in split_order
            if split in all_eval[model_name]
        }
        for model_name in all_eval
    }
).T

fig, axes = plt.subplots(1, 2, figsize=(18, 6))
sns.heatmap(exact_df, annot=True, fmt=".3f", cmap="YlGnBu", vmin=0.0, vmax=1.0, ax=axes[0])
axes[0].set_title("Exact match by model and split")
axes[0].set_xlabel("Split")
axes[0].set_ylabel("Model")

sns.heatmap(distance_df, annot=True, fmt=".3f", cmap="YlOrBr", vmin=0.0, vmax=1.0, ax=axes[1])
axes[1].set_title("Distance-wise accuracy by model and split")
axes[1].set_xlabel("Split")
axes[1].set_ylabel("Model")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. OOD Gap Relative to ID
#
# Эти графики удобны, когда хочется показать не только абсолютное качество, но и устойчивость модели при сдвиге распределения.

# %%
id_scores = exact_df["ID"]
drop_df = exact_df.apply(lambda col: id_scores - col)
ood_drop_df = drop_df[[col for col in exact_df.columns if col != "ID"]]

aux_candidates = [name for name in all_eval if " + Aux " in name]
best_aux_name = max(
    aux_candidates,
    key=lambda name: np.mean([all_eval[name][split]["exact_match"] for split in split_order if split != "test_id"]),
)

representative_models = []
for candidate in [f"SFT {SFT_LAYERS[0]}L", f"SFT {SFT_LAYERS[-1]}L", best_aux_name]:
    if candidate in all_eval and candidate not in representative_models:
        representative_models.append(candidate)

fig, axes = plt.subplots(1, 2, figsize=(18, 5))
sns.heatmap(ood_drop_df * 100, annot=True, fmt=".1f", cmap="Reds", vmin=0.0, ax=axes[0])
axes[0].set_title("Exact-match drop vs ID (percentage points)")
axes[0].set_xlabel("OOD split")
axes[0].set_ylabel("Model")

x = np.arange(len(split_order))
for model_name in representative_models:
    ys = [all_eval[model_name][split]["exact_match"] for split in split_order]
    axes[1].plot(x, ys, marker="o", linewidth=2, label=model_name)
axes[1].set_xticks(x)
axes[1].set_xticklabels([split_labels[split] for split in split_order], rotation=30, ha="right")
axes[1].set_ylim(0.0, 1.02)
axes[1].set_ylabel("Exact match")
axes[1].set_title("Representative model profiles across splits")
axes[1].grid(alpha=0.2)
axes[1].legend()

plt.tight_layout()
plt.show()
