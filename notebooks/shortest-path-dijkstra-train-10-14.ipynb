# %% [markdown]
# # Fixed-Size Shortest Paths / Dijkstra
#
# Эксперимент `shortest_path_dijkstra/`: фиксированный weighted graph, output фиксированной длины `dist[0..N-1]`, auxiliary loss на внутреннее состояние алгоритма Дейкстры (`dist[]`, `visited[]`) на output-позициях.

# %% [markdown]
# ## 0. Setup

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
personal_token = user_secrets.get_secret("GITHUB_TOKEN")

# !rm -rf transformer-analyzing
# !git clone https://{personal_token}@github.com/maximvw/transformer-analyzing.git transformer-analyzing
# %cd transformer-analyzing


import sys
from pathlib import Path
import json
import torch

print("Python:", sys.executable)
PYTHON = sys.executable
print("CUDA available:", torch.cuda.is_available())
print("CUDA devices:", torch.cuda.device_count())
for i in range(torch.cuda.device_count()):
    props = torch.cuda.get_device_properties(i)
    print(f"GPU {i}: {props.name} | {props.total_memory / 1e9:.1f} GB")

ROOT = Path.cwd()
# Out:
# Cloning into 'transformer-analyzing'...
# remote: Enumerating objects: 561, done.
# remote: Counting objects: 100% (223/223), done.
# remote: Compressing objects: 100% (173/173), done.
# remote: Total 561 (delta 85), reused 164 (delta 48), pack-reused 338 (from 1)
# Receiving objects: 100% (561/561), 17.71 MiB | 33.96 MiB/s, done.
# Resolving deltas: 100% (232/232), done.
# /kaggle/working/transformer-analyzing
# Python: /usr/bin/python3
# CUDA available: True
# CUDA devices: 2
# GPU 0: Tesla T4 | 15.6 GB
# GPU 1: Tesla T4 | 15.6 GB

# %% [markdown]
# ## 1. Конфиг
#
# Сверху есть переключатель `CONFIG_MODE`: `"smoke"` для быстрой проверки, что тетрадка запускается, и `"full"` для основного эксперимента.

# %%
CONFIG_MODE = "full"  # "smoke" | "full"

SMOKE_CONFIG = {
    "graph_n": 6,
    "max_weight": 5,
    "max_distance": 40,
    "max_seq_len": 64,
    "n_train": 256,
    "n_val": 64,
    "n_test": 64,
    "d_model": 16,
    "n_head": 4,
    "batch_size": 32,
    "epochs": 2,
    "patience": 1,
    "lr": 1e-4,
    "aux_lambdas": [0.1, 1.0, 10.0],
    "sft_layers": [10, 14],
    "aux_layers": [10, 14],
}

FULL_CONFIG = {
    "graph_n": 10,
    "max_weight": 9,
    "max_distance": 99,
    "max_seq_len": 128,
    "n_train": 80000,
    "n_val": 2000,
    "n_test": 2000,
    "d_model": 128,
    "n_head": 4,
    "batch_size": 128,
    "epochs": 50,
    "patience": 8,
    "lr": 1e-4,
    "aux_lambdas": [0.1, 1.0, 10.0],
    "sft_layers": [10, 14],
    "aux_layers": [10, 14],
}

CONFIGS = {
    "smoke": SMOKE_CONFIG,
    "full": FULL_CONFIG,
}
assert CONFIG_MODE in CONFIGS, f"Unknown CONFIG_MODE: {CONFIG_MODE}"
CFG = CONFIGS[CONFIG_MODE]

GRAPH_N = CFG["graph_n"]
MAX_WEIGHT = CFG["max_weight"]
MAX_DISTANCE = CFG["max_distance"]
MAX_SEQ_LEN = CFG["max_seq_len"]
N_TRAIN = CFG["n_train"]
N_VAL = CFG["n_val"]
N_TEST = CFG["n_test"]
D_MODEL = CFG["d_model"]
N_HEAD = CFG["n_head"]
BATCH_SIZE = CFG["batch_size"]
EPOCHS = CFG["epochs"]
PATIENCE = CFG["patience"]
LR = CFG["lr"]
AUX_LAMBDAS = CFG["aux_lambdas"]
SFT_LAYERS = CFG["sft_layers"]
AUX_LAYERS = CFG["aux_layers"]

RUN_TAG = f"{CONFIG_MODE}_n{GRAPH_N}"
DATA_DIR = ROOT / "shortest_path_dijkstra" / f"data_{RUN_TAG}"
CKPT_DIR = ROOT / "checkpoints" / f"shortest_path_dijkstra_{RUN_TAG}"
DATA_DIR.mkdir(parents=True, exist_ok=True)
CKPT_DIR.mkdir(parents=True, exist_ok=True)

print(f"CONFIG_MODE={CONFIG_MODE}")
print(json.dumps(CFG, indent=2))
print("DATA_DIR:", DATA_DIR)
print("CKPT_DIR:", CKPT_DIR)
# Out:
# CONFIG_MODE=full
# {
#   "graph_n": 10,
#   "max_weight": 9,
#   "max_distance": 99,
#   "max_seq_len": 128,
#   "n_train": 80000,
#   "n_val": 2000,
#   "n_test": 2000,
#   "d_model": 128,
#   "n_head": 4,
#   "batch_size": 128,
#   "epochs": 50,
#   "patience": 8,
#   "lr": 0.0001,
#   "aux_lambdas": [
#     0.1,
#     1.0,
#     10.0
#   ],
#   "sft_layers": [
#     10,
#     14
#   ],
#   "aux_layers": [
#     10,
#     14
#   ]
# }
# DATA_DIR: /kaggle/working/transformer-analyzing/shortest_path_dijkstra/data_full_n10
# CKPT_DIR: /kaggle/working/transformer-analyzing/checkpoints/shortest_path_dijkstra_full_n10

# %% [markdown]
# ## 2. Генерация данных

# %%
# !$PYTHON -m shortest_path_dijkstra.scripts.generate_data \
    --output_dir "$DATA_DIR" \
    --n_train $N_TRAIN \
    --n_val $N_VAL \
    --n_test $N_TEST \
    --graph_n $GRAPH_N \
    --edge_prob 0.25 \
    --dense_edge_prob 0.55 \
    --max_weight $MAX_WEIGHT \
    --max_distance $MAX_DISTANCE \
    --seed 42

for path in sorted(DATA_DIR.glob("*.json")):
    with open(path) as f:
        items = json.load(f)
    print(f"{path.name}: {len(items)} examples")
    if items:
        ex = items[0]
        print(" N:", ex["n"], "edges:", ex["num_edges"], "type:", ex["split_type"])
        print(" source:", ex["source"])
        print(" first row:", ex["matrix"][0])
        print(" distances:", ex["distances"])
        print(" first dist states:", ex["dist_states"][:2])
# Out:
# train: n=80000 | graph_N=10 | avg_edges=29.26 max_dist=56 | types={'random': 80000}
# val: n=2000 | graph_N=10 | avg_edges=29.11 max_dist=43 | types={'random': 2000}
# test_id: n=2000 | graph_N=10 | avg_edges=29.16 max_dist=52 | types={'random': 2000}
# test_ood_dense: n=2000 | graph_N=10 | avg_edges=53.79 max_dist=20 | types={'dense': 2000}
# test_ood_long_chain: n=2000 | graph_N=10 | avg_edges=14.07 max_dist=18 | types={'long_chain': 2000}
# test_ood_adversarial_direct: n=2000 | graph_N=10 | avg_edges=20.45 max_dist=9 | types={'adversarial_direct': 2000}
# test_ood_equal_ties: n=2000 | graph_N=10 | avg_edges=24.12 max_dist=18 | types={'equal_ties': 2000}
# test_ood_layered_bipartite: n=2000 | graph_N=10 | avg_edges=25.83 max_dist=10 | types={'layered_bipartite': 2000}
# test_ood_near_complete_hidden_path: n=2000 | graph_N=10 | avg_edges=90.00 max_dist=9 | types={'near_complete_hidden_path': 2000}
# test_id.json: 2000 examples
#  N: 10 edges: 30 type: random
#  source: 0
#  first row: [0, None, None, 1, 4, 8, None, 2, None, None]
#  distances: [0, 3, 7, 1, 4, 6, 10, 2, 6, 8]
#  first dist states: [[0, 99, 99, 1, 4, 8, 99, 2, 99, 99], [0, 3, 99, 1, 4, 6, 99, 2, 99, 99]]
# test_ood_adversarial_direct.json: 2000 examples
#  N: 10 edges: 22 type: adversarial_direct
#  source: 0
#  first row: [0, 9, 7, 9, 5, 8, 1, 9, 5, 9]
#  distances: [0, 6, 4, 5, 3, 5, 1, 4, 2, 6]
#  first dist states: [[0, 9, 7, 9, 5, 8, 1, 9, 5, 9], [0, 9, 7, 9, 5, 8, 1, 4, 2, 9]]
# test_ood_dense.json: 2000 examples
#  N: 10 edges: 48 type: dense
#  source: 0
#  first row: [0, 9, None, None, 9, 5, None, 8, None, None]
#  distances: [0, 9, 13, 9, 9, 5, 11, 8, 11, 11]
#  first dist states: [[0, 9, 99, 99, 9, 5, 99, 8, 99, 99], [0, 9, 99, 99, 9, 5, 99, 8, 99, 11]]
# test_ood_equal_ties.json: 2000 examples
#  N: 10 edges: 24 type: equal_ties
#  source: 0
#  first row: [0, 2, 2, 2, 2, None, None, 5, None, None]
#  distances: [0, 2, 2, 2, 2, 4, 4, 4, 4, 4]
#  first dist states: [[0, 2, 2, 2, 2, 99, 99, 5, 99, 99], [0, 2, 2, 2, 2, 99, 4, 4, 4, 99]]
# test_ood_layered_bipartite.json: 2000 examples
#  N: 10 edges: 27 type: layered_bipartite
#  source: 0
#  first row: [0, None, 7, 9, 9, 9, None, 1, 7, 9]
#  distances: [0, 10, 7, 9, 9, 8, 9, 1, 7, 2]
#  first dist states: [[0, 99, 7, 9, 9, 9, 99, 1, 7, 9], [0, 10, 7, 9, 9, 9, 9, 1, 7, 2]]
# test_ood_long_chain.json: 2000 examples
#  N: 10 edges: 15 type: long_chain
#  source: 0
#  first row: [0, None, None, None, None, None, 8, None, None, 1]
#  distances: [0, 3, 13, 9, 6, 13, 7, 12, 10, 1]
#  first dist states: [[0, 99, 99, 99, 99, 99, 8, 99, 99, 1], [0, 3, 99, 99, 99, 99, 8, 99, 10, 1]]
# test_ood_near_complete_hidden_path.json: 2000 examples
#  N: 10 edges: 90 type: near_complete_hidden_path
#  source: 0
#  first row: [0, 9, 7, 9, 5, 8, 1, 7, 7, 6]
#  distances: [0, 8, 5, 6, 2, 8, 1, 4, 7, 3]
#  first dist states: [[0, 9, 7, 9, 5, 8, 1, 7, 7, 6], [0, 8, 7, 9, 2, 8, 1, 7, 7, 6]]
# train.json: 80000 examples
#  N: 10 edges: 29 type: random
#  source: 0
#  first row: [0, 9, None, 7, None, None, None, None, 7, None]
#  distances: [0, 9, 8, 7, 10, 9, 12, 11, 7, 12]
#  first dist states: [[0, 9, 99, 7, 99, 99, 99, 99, 7, 99], [0, 9, 8, 7, 99, 99, 99, 99, 7, 12]]
# val.json: 2000 examples
#  N: 10 edges: 30 type: random
#  source: 0
#  first row: [0, None, 8, None, 5, None, None, None, 6, 2]
#  distances: [0, 4, 8, 7, 5, 6, 9, 10, 3, 2]
#  first dist states: [[0, 99, 8, 99, 5, 99, 99, 99, 6, 2], [0, 99, 8, 7, 5, 6, 99, 99, 3, 2]]

# %% [markdown]
# ## 3. SFT depth ablation

# %%
for n_layer in SFT_LAYERS:
    print(f"{'=' * 70}")
    print(f"Training Shortest Path SFT {n_layer}L")
    print(f"{'=' * 70}")
    SAVE_DIR = CKPT_DIR / f"dijkstra_sft_{n_layer}L"
    !"$PYTHON" -m shortest_path_dijkstra.src.train \
        --train_path "{DATA_DIR / 'train.json'}" \
        --val_path "{DATA_DIR / 'val.json'}" \
        --graph_n {GRAPH_N} \
        --max_weight {MAX_WEIGHT} \
        --max_distance {MAX_DISTANCE} \
        --d_model {D_MODEL} --n_layer {n_layer} --n_head {N_HEAD} \
        --max_seq_len {MAX_SEQ_LEN} \
        --lr {LR} --weight_decay 0.01 \
        --batch_size {BATCH_SIZE} --epochs {EPOCHS} --patience {PATIENCE} \
        --lambda_state 0.0 \
        --num_workers 2 \
        --save_dir "{SAVE_DIR}" \
        --seed 42
# Out:
# ======================================================================
# Training Shortest Path SFT 10L
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 2,015,616
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=2.3551 tok_acc=0.3801 | val loss=1.6993 tok_acc=0.4839
# Epoch   1 | train loss=1.6011 tok_acc=0.4896 | val loss=1.5441 tok_acc=0.4955
# Epoch   2 | train loss=1.4464 tok_acc=0.5225 | val loss=1.2802 tok_acc=0.5617
# Epoch   3 | train loss=1.1156 tok_acc=0.6196 | val loss=0.9619 tok_acc=0.6708
# Epoch   4 | train loss=0.8666 tok_acc=0.7027 | val loss=0.7741 tok_acc=0.7345
# Epoch   5 | train loss=0.6897 tok_acc=0.7605 | val loss=0.6357 tok_acc=0.7805
# Epoch   6 | train loss=0.5736 tok_acc=0.8031 | val loss=0.5413 tok_acc=0.8158
# Epoch   7 | train loss=0.5006 tok_acc=0.8269 | val loss=0.4866 tok_acc=0.8308
# Epoch   8 | train loss=0.4489 tok_acc=0.8421 | val loss=0.4399 tok_acc=0.8455
# Epoch   9 | train loss=0.3948 tok_acc=0.8589 | val loss=0.3844 tok_acc=0.8615
# Epoch  10 | train loss=0.3365 tok_acc=0.8779 | val loss=0.3378 tok_acc=0.8757
# Epoch  11 | train loss=0.2930 tok_acc=0.8938 | val loss=0.2820 tok_acc=0.8992
# Epoch  12 | train loss=0.2634 tok_acc=0.9043 | val loss=0.2642 tok_acc=0.9054
# Epoch  13 | train loss=0.2418 tok_acc=0.9118 | val loss=0.2453 tok_acc=0.9125
# Epoch  14 | train loss=0.2250 tok_acc=0.9184 | val loss=0.2374 tok_acc=0.9130
# Epoch  26 | train loss=0.1508 tok_acc=0.9488 | val loss=0.1733 tok_acc=0.9420
# Epoch  27 | train loss=0.1433 tok_acc=0.9511 | val loss=0.1513 tok_acc=0.9502
# Epoch  28 | train loss=0.1365 tok_acc=0.9537 | val loss=0.1384 tok_acc=0.9535
# Epoch  29 | train loss=0.1335 tok_acc=0.9550 | val loss=0.1627 tok_acc=0.9457
# Epoch  30 | train loss=0.1288 tok_acc=0.9563 | val loss=0.1364 tok_acc=0.9559
# Epoch  31 | train loss=0.1248 tok_acc=0.9581 | val loss=0.1304 tok_acc=0.9575
# Epoch  32 | train loss=0.1214 tok_acc=0.9589 | val loss=0.1450 tok_acc=0.9525
# Epoch  33 | train loss=0.1170 tok_acc=0.9601 | val loss=0.1383 tok_acc=0.9564
# Epoch  34 | train loss=0.1128 tok_acc=0.9616 | val loss=0.1281 tok_acc=0.9572
# Epoch  35 | train loss=0.1104 tok_acc=0.9626 | val loss=0.1212 tok_acc=0.9593
# Epoch  36 | train loss=0.1049 tok_acc=0.9644 | val loss=0.1217 tok_acc=0.9616
# Epoch  37 | train loss=0.1019 tok_acc=0.9651 | val loss=0.1245 tok_acc=0.9578
# Epoch  38 | train loss=0.0991 tok_acc=0.9662 | val loss=0.1221 tok_acc=0.9584
# Epoch  39 | train loss=0.0951 tok_acc=0.9676 | val loss=0.1103 tok_acc=0.9645
# Epoch  40 | train loss=0.0923 tok_acc=0.9684 | val loss=0.1044 tok_acc=0.9640
# Epoch  41 | train loss=0.0896 tok_acc=0.9693 | val loss=0.0959 tok_acc=0.9675
# Epoch  42 | train loss=0.0880 tok_acc=0.9700 | val loss=0.0947 tok_acc=0.9671
# Epoch  43 | train loss=0.0851 tok_acc=0.9710 | val loss=0.0982 tok_acc=0.9677
# Epoch  44 | train loss=0.0836 tok_acc=0.9716 | val loss=0.1031 tok_acc=0.9640
# Epoch  45 | train loss=0.0805 tok_acc=0.9724 | val loss=0.0961 tok_acc=0.9678
# Epoch  46 | train loss=0.0789 tok_acc=0.9728 | val loss=0.1037 tok_acc=0.9672
# Epoch  47 | train loss=0.0771 tok_acc=0.9737 | val loss=0.0967 tok_acc=0.9682
# Epoch  48 | train loss=0.0746 tok_acc=0.9746 | val loss=0.1021 tok_acc=0.9660
# Epoch  49 | train loss=0.0742 tok_acc=0.9749 | val loss=0.1002 tok_acc=0.9685
# Training complete. Best val loss: 0.0947

# %% [markdown]
# ## 4. Auxiliary Loss Across Depths

# %%
for n_layer in AUX_LAYERS:
    for aux_lambda in AUX_LAMBDAS:
        print(f"{'=' * 70}")
        print(f"Training Shortest Path {n_layer}L + Aux (lambda={aux_lambda})")
        print(f"{'=' * 70}")
        SAVE_DIR = CKPT_DIR / f"dijkstra_aux_{n_layer}L_lambda{aux_lambda}"
        !"$PYTHON" -m shortest_path_dijkstra.src.train \
            --train_path "{DATA_DIR / 'train.json'}" \
            --val_path "{DATA_DIR / 'val.json'}" \
            --graph_n {GRAPH_N} \
            --max_weight {MAX_WEIGHT} \
            --max_distance {MAX_DISTANCE} \
            --d_model {D_MODEL} --n_layer {n_layer} --n_head {N_HEAD} \
            --max_seq_len {MAX_SEQ_LEN} \
            --lr {LR} --weight_decay 0.01 \
            --batch_size {BATCH_SIZE} --epochs {EPOCHS} --patience {PATIENCE} \
            --lambda_state {aux_lambda} \
            --num_workers 2 \
            --save_dir "{SAVE_DIR}" \
            --seed 42
# Out:
# ======================================================================
# Training Shortest Path 10L + Aux (lambda=0.1)
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 2,015,616
# Probe parameters: 134,640
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=2.7348 tok_acc=0.3801 | val loss=2.0251 tok_acc=0.4855
# Epoch   1 | train loss=1.8977 tok_acc=0.4925 | val loss=1.8131 tok_acc=0.5095
# Epoch   2 | train loss=1.6048 tok_acc=0.5676 | val loss=1.4849 tok_acc=0.6030
# Epoch   3 | train loss=1.3863 tok_acc=0.6309 | val loss=1.2783 tok_acc=0.6689
# Epoch   4 | train loss=1.1506 tok_acc=0.7031 | val loss=1.0680 tok_acc=0.7216
# Epoch   5 | train loss=1.0110 tok_acc=0.7445 | val loss=0.9527 tok_acc=0.7620
# Epoch   6 | train loss=0.8937 tok_acc=0.7826 | val loss=0.8364 tok_acc=0.8034
# Epoch   7 | train loss=0.7958 tok_acc=0.8181 | val loss=0.7789 tok_acc=0.8249
# Epoch   8 | train loss=0.7219 tok_acc=0.8417 | val loss=0.7173 tok_acc=0.8420
# Epoch   9 | train loss=0.6630 tok_acc=0.8600 | val loss=0.6549 tok_acc=0.8619
# Epoch  10 | train loss=0.6231 tok_acc=0.8736 | val loss=0.6297 tok_acc=0.8693
# Epoch  11 | train loss=0.5953 tok_acc=0.8826 | val loss=0.6090 tok_acc=0.8785
# Epoch  12 | train loss=0.5740 tok_acc=0.8899 | val loss=0.5981 tok_acc=0.8850
# Epoch  13 | train loss=0.5524 tok_acc=0.8965 | val loss=0.5572 tok_acc=0.8925
# Epoch  14 | train loss=0.5326 tok_acc=0.9025 | val loss=0.5209 tok_acc=0.9060
# Epoch  15 | train loss=0.5201 tok_acc=0.9067 | val loss=0.5232 tok_acc=0.9043
# Epoch  16 | train loss=0.5065 tok_acc=0.9107 | val loss=0.5140 tok_acc=0.9075
# Epoch  17 | train loss=0.4939 tok_acc=0.9142 | val loss=0.5122 tok_acc=0.9086
# Epoch  18 | train loss=0.4813 tok_acc=0.9176 | val loss=0.4828 tok_acc=0.9152
# Epoch  19 | train loss=0.4703 tok_acc=0.9202 | val loss=0.4787 tok_acc=0.9163
# Epoch  20 | train loss=0.4610 tok_acc=0.9223 | val loss=0.4680 tok_acc=0.9205
# Epoch  21 | train loss=0.4524 tok_acc=0.9237 | val loss=0.4684 tok_acc=0.9193
# Epoch  22 | train loss=0.4394 tok_acc=0.9266 | val loss=0.4440 tok_acc=0.9251
# Epoch  23 | train loss=0.4303 tok_acc=0.9279 | val loss=0.4265 tok_acc=0.9299
# Epoch  24 | train loss=0.4167 tok_acc=0.9305 | val loss=0.4306 tok_acc=0.9265
# Epoch  25 | train loss=0.4067 tok_acc=0.9314 | val loss=0.4088 tok_acc=0.9299
# Epoch  26 | train loss=0.3930 tok_acc=0.9338 | val loss=0.4120 tok_acc=0.9288
# Epoch  27 | train loss=0.3840 tok_acc=0.9347 | val loss=0.3960 tok_acc=0.9296
# Epoch  28 | train loss=0.3723 tok_acc=0.9365 | val loss=0.3802 tok_acc=0.9349
# Epoch  29 | train loss=0.3608 tok_acc=0.9380 | val loss=0.3812 tok_acc=0.9334
# Epoch  30 | train loss=0.3508 tok_acc=0.9394 | val loss=0.3603 tok_acc=0.9366
# Epoch  31 | train loss=0.3403 tok_acc=0.9407 | val loss=0.3501 tok_acc=0.9377
# Epoch  32 | train loss=0.3284 tok_acc=0.9421 | val loss=0.3391 tok_acc=0.9381
# Epoch  33 | train loss=0.3181 tok_acc=0.9435 | val loss=0.3256 tok_acc=0.9401
# Epoch  34 | train loss=0.3100 tok_acc=0.9448 | val loss=0.3382 tok_acc=0.9352
# Epoch  35 | train loss=0.3032 tok_acc=0.9455 | val loss=0.3119 tok_acc=0.9432
# Epoch  36 | train loss=0.2970 tok_acc=0.9465 | val loss=0.3306 tok_acc=0.9339
# Epoch  37 | train loss=0.2889 tok_acc=0.9476 | val loss=0.2984 tok_acc=0.9441
# Epoch  38 | train loss=0.2836 tok_acc=0.9486 | val loss=0.2953 tok_acc=0.9435
# Epoch  39 | train loss=0.2766 tok_acc=0.9500 | val loss=0.2874 tok_acc=0.9458
# Epoch  40 | train loss=0.2714 tok_acc=0.9508 | val loss=0.2842 tok_acc=0.9461
# Epoch  41 | train loss=0.2662 tok_acc=0.9519 | val loss=0.2883 tok_acc=0.9438
# Epoch  42 | train loss=0.2640 tok_acc=0.9521 | val loss=0.2761 tok_acc=0.9485
# Epoch  43 | train loss=0.2600 tok_acc=0.9526 | val loss=0.2679 tok_acc=0.9501
# Epoch  44 | train loss=0.2557 tok_acc=0.9537 | val loss=0.2898 tok_acc=0.9402
# Epoch  45 | train loss=0.2515 tok_acc=0.9540 | val loss=0.2720 tok_acc=0.9487
# Epoch  46 | train loss=0.2462 tok_acc=0.9552 | val loss=0.2590 tok_acc=0.9531
# Epoch  47 | train loss=0.2415 tok_acc=0.9564 | val loss=0.2603 tok_acc=0.9499
# Epoch  48 | train loss=0.2391 tok_acc=0.9565 | val loss=0.2539 tok_acc=0.9517
# Epoch  49 | train loss=0.2346 tok_acc=0.9573 | val loss=0.2554 tok_acc=0.9517
# Training complete. Best val loss: 0.2539
# ======================================================================
# Training Shortest Path 10L + Aux (lambda=1.0)
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 2,015,616
# Probe parameters: 134,640
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=5.9540 tok_acc=0.3737 | val loss=4.6239 tok_acc=0.4869
# Epoch   1 | train loss=4.3896 tok_acc=0.4885 | val loss=4.2585 tok_acc=0.4910
# Epoch   2 | train loss=4.1184 tok_acc=0.5177 | val loss=3.9662 tok_acc=0.5490
# Epoch   3 | train loss=3.7053 tok_acc=0.6106 | val loss=3.3803 tok_acc=0.6912
# Epoch  35 | train loss=0.6802 tok_acc=0.9484 | val loss=0.7034 tok_acc=0.9417
# Epoch  36 | train loss=0.6601 tok_acc=0.9497 | val loss=0.6859 tok_acc=0.9438
# Epoch  37 | train loss=0.6415 tok_acc=0.9510 | val loss=0.6579 tok_acc=0.9492
# Epoch  38 | train loss=0.6233 tok_acc=0.9524 | val loss=0.6493 tok_acc=0.9471
# Epoch  39 | train loss=0.6063 tok_acc=0.9532 | val loss=0.6479 tok_acc=0.9440
# Epoch  40 | train loss=0.5898 tok_acc=0.9546 | val loss=0.6292 tok_acc=0.9479
# Epoch  41 | train loss=0.5752 tok_acc=0.9556 | val loss=0.6105 tok_acc=0.9493
# Epoch  42 | train loss=0.5596 tok_acc=0.9566 | val loss=0.5888 tok_acc=0.9528
# Epoch  43 | train loss=0.5458 tok_acc=0.9577 | val loss=0.5828 tok_acc=0.9503
# Epoch  44 | train loss=0.5317 tok_acc=0.9587 | val loss=0.5793 tok_acc=0.9477
# Epoch  45 | train loss=0.5184 tok_acc=0.9597 | val loss=0.5596 tok_acc=0.9512
# Epoch  46 | train loss=0.5055 tok_acc=0.9604 | val loss=0.5462 tok_acc=0.9547
# Epoch  47 | train loss=0.4937 tok_acc=0.9612 | val loss=0.5335 tok_acc=0.9529
# Epoch  48 | train loss=0.4816 tok_acc=0.9623 | val loss=0.5260 tok_acc=0.9530
# Epoch  49 | train loss=0.4687 tok_acc=0.9633 | val loss=0.5162 tok_acc=0.9555
# Training complete. Best val loss: 0.5162
# ======================================================================
# Training Shortest Path 10L + Aux (lambda=10.0)
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 2,015,616
# Probe parameters: 134,640
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=37.2896 tok_acc=0.2973 | val loss=29.9392 tok_acc=0.3932
# Epoch   1 | train loss=28.5283 tok_acc=0.4456 | val loss=27.2955 tok_acc=0.4748
# Epoch   2 | train loss=26.2953 tok_acc=0.4827 | val loss=25.2958 tok_acc=0.4889
# Epoch   3 | train loss=24.3122 tok_acc=0.4904 | val loss=23.3605 tok_acc=0.4940
# Epoch   4 | train loss=22.4698 tok_acc=0.4936 | val loss=21.6746 tok_acc=0.4963
# Epoch   5 | train loss=20.8307 tok_acc=0.4975 | val loss=20.0750 tok_acc=0.5003
# Epoch   6 | train loss=19.3988 tok_acc=0.5004 | val loss=18.7512 tok_acc=0.5020
# Epoch   7 | train loss=18.0938 tok_acc=0.5048 | val loss=17.5432 tok_acc=0.5048
# Epoch   8 | train loss=16.8407 tok_acc=0.5113 | val loss=16.2835 tok_acc=0.5170
# Epoch   9 | train loss=15.4472 tok_acc=0.5245 | val loss=14.7500 tok_acc=0.5336
# Epoch  10 | train loss=14.0360 tok_acc=0.5481 | val loss=13.4598 tok_acc=0.5582
# Epoch  11 | train loss=12.8499 tok_acc=0.5716 | val loss=12.3916 tok_acc=0.5836
# Epoch  12 | train loss=11.9074 tok_acc=0.5936 | val loss=11.5901 tok_acc=0.5957
# Epoch  44 | train loss=3.8202 tok_acc=0.8585 | val loss=3.9742 tok_acc=0.8500
# Epoch  45 | train loss=3.7314 tok_acc=0.8601 | val loss=3.8930 tok_acc=0.8487
# Epoch  46 | train loss=3.6516 tok_acc=0.8624 | val loss=3.8122 tok_acc=0.8540
# Epoch  47 | train loss=3.5602 tok_acc=0.8644 | val loss=3.7318 tok_acc=0.8535
# Epoch  48 | train loss=3.4683 tok_acc=0.8654 | val loss=3.6137 tok_acc=0.8571
# Epoch  49 | train loss=3.3933 tok_acc=0.8672 | val loss=3.5459 tok_acc=0.8620
# Training complete. Best val loss: 3.5459
# ======================================================================
# Training Shortest Path 14L + Aux (lambda=0.1)
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 2,808,704
# Probe parameters: 134,640
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=2.7374 tok_acc=0.3716 | val loss=2.0201 tok_acc=0.4847
# Epoch   1 | train loss=1.8933 tok_acc=0.4921 | val loss=1.8043 tok_acc=0.5029
# Epoch   2 | train loss=1.5799 tok_acc=0.5714 | val loss=1.3187 tok_acc=0.6490
# Epoch   3 | train loss=1.1430 tok_acc=0.7042 | val loss=1.0477 tok_acc=0.7321
# Epoch   4 | train loss=0.9585 tok_acc=0.7581 | val loss=0.8985 tok_acc=0.7775
# Epoch   5 | train loss=0.8429 tok_acc=0.7964 | val loss=0.8214 tok_acc=0.7978
# Epoch   6 | train loss=0.7577 tok_acc=0.8222 | val loss=0.7217 tok_acc=0.8350
# Epoch   7 | train loss=0.6667 tok_acc=0.8526 | val loss=0.6360 tok_acc=0.8637
# Epoch   8 | train loss=0.6139 tok_acc=0.8711 | val loss=0.5889 tok_acc=0.8795
# Epoch   9 | train loss=0.5761 tok_acc=0.8842 | val loss=0.5603 tok_acc=0.8910
# Epoch  10 | train loss=0.5521 tok_acc=0.8926 | val loss=0.5473 tok_acc=0.8944
# Epoch  11 | train loss=0.5283 tok_acc=0.9007 | val loss=0.5310 tok_acc=0.9007
# Epoch  12 | train loss=0.5100 tok_acc=0.9066 | val loss=0.5078 tok_acc=0.9061
# Epoch  13 | train loss=0.4938 tok_acc=0.9119 | val loss=0.4839 tok_acc=0.9142
# Epoch  14 | train loss=0.4796 tok_acc=0.9162 | val loss=0.4939 tok_acc=0.9100
# Epoch  15 | train loss=0.4645 tok_acc=0.9203 | val loss=0.4875 tok_acc=0.9140
# Epoch  16 | train loss=0.4508 tok_acc=0.9238 | val loss=0.4724 tok_acc=0.9120
# Epoch  17 | train loss=0.4366 tok_acc=0.9272 | val loss=0.4464 tok_acc=0.9204
# Epoch  18 | train loss=0.4213 tok_acc=0.9308 | val loss=0.4191 tok_acc=0.9293
# Epoch  19 | train loss=0.4064 tok_acc=0.9333 | val loss=0.4061 tok_acc=0.9324
# Epoch  20 | train loss=0.3900 tok_acc=0.9364 | val loss=0.3939 tok_acc=0.9355
# Epoch  21 | train loss=0.3772 tok_acc=0.9381 | val loss=0.3953 tok_acc=0.9309
# Epoch  22 | train loss=0.3634 tok_acc=0.9402 | val loss=0.3737 tok_acc=0.9358
# Epoch   2 | train loss=4.1818 tok_acc=0.4939 | val loss=4.0563 tok_acc=0.5041
# Epoch   3 | train loss=3.8006 tok_acc=0.5722 | val loss=3.5796 tok_acc=0.6371
# Epoch   4 | train loss=3.4298 tok_acc=0.6559 | val loss=3.2845 tok_acc=0.6853
# Epoch   5 | train loss=3.0994 tok_acc=0.7200 | val loss=2.9473 tok_acc=0.7432
# Epoch   6 | train loss=2.8173 tok_acc=0.7653 | val loss=2.7003 tok_acc=0.7763
# Epoch   7 | train loss=2.5682 tok_acc=0.8017 | val loss=2.4563 tok_acc=0.8207
# Epoch   8 | train loss=2.3523 tok_acc=0.8239 | val loss=2.2475 tok_acc=0.8370
# Epoch   9 | train loss=2.1487 tok_acc=0.8398 | val loss=2.0713 tok_acc=0.8438
# Epoch  10 | train loss=1.9617 tok_acc=0.8560 | val loss=1.8779 tok_acc=0.8599
# Epoch  11 | train loss=1.7991 tok_acc=0.8710 | val loss=1.7354 tok_acc=0.8745
# Epoch  12 | train loss=1.6654 tok_acc=0.8840 | val loss=1.6235 tok_acc=0.8871
# Epoch  13 | train loss=1.5577 tok_acc=0.8938 | val loss=1.5182 tok_acc=0.8980
# Epoch  14 | train loss=1.4627 tok_acc=0.9035 | val loss=1.4340 tok_acc=0.9015
# Epoch  15 | train loss=1.3805 tok_acc=0.9102 | val loss=1.3692 tok_acc=0.9028
# Epoch  16 | train loss=1.3103 tok_acc=0.9161 | val loss=1.2978 tok_acc=0.9155
# Epoch  17 | train loss=1.2471 tok_acc=0.9212 | val loss=1.2528 tok_acc=0.9140
# Epoch  18 | train loss=1.1895 tok_acc=0.9254 | val loss=1.1908 tok_acc=0.9183
# Epoch  19 | train loss=1.1383 tok_acc=0.9288 | val loss=1.1648 tok_acc=0.9129
# Epoch  20 | train loss=1.0932 tok_acc=0.9311 | val loss=1.1005 tok_acc=0.9212
# Epoch  21 | train loss=1.0489 tok_acc=0.9346 | val loss=1.0473 tok_acc=0.9342
# Epoch  22 | train loss=1.0047 tok_acc=0.9379 | val loss=1.0124 tok_acc=0.9312
# Epoch  23 | train loss=0.9655 tok_acc=0.9398 | val loss=0.9819 tok_acc=0.9312
# Epoch  24 | train loss=0.9315 tok_acc=0.9423 | val loss=0.9394 tok_acc=0.9372
# Epoch  25 | train loss=0.8964 tok_acc=0.9443 | val loss=0.8939 tok_acc=0.9421
# Epoch  26 | train loss=0.8629 tok_acc=0.9470 | val loss=0.8980 tok_acc=0.9362
# Epoch  27 | train loss=0.8345 tok_acc=0.9481 | val loss=0.8447 tok_acc=0.9425
# Epoch  28 | train loss=0.8067 tok_acc=0.9502 | val loss=0.8086 tok_acc=0.9486
# Epoch  29 | train loss=0.7801 tok_acc=0.9520 | val loss=0.7866 tok_acc=0.9505
# Epoch  30 | train loss=0.7567 tok_acc=0.9526 | val loss=0.7681 tok_acc=0.9485
# Epoch  31 | train loss=0.7350 tok_acc=0.9542 | val loss=0.7544 tok_acc=0.9509
# Epoch  32 | train loss=0.7143 tok_acc=0.9552 | val loss=0.7420 tok_acc=0.9452
# Epoch  33 | train loss=0.6930 tok_acc=0.9567 | val loss=0.7156 tok_acc=0.9509
# Epoch  34 | train loss=0.6747 tok_acc=0.9581 | val loss=0.6948 tok_acc=0.9532
# Epoch  35 | train loss=0.6569 tok_acc=0.9590 | val loss=0.6838 tok_acc=0.9539
# Epoch  36 | train loss=0.6393 tok_acc=0.9606 | val loss=0.6653 tok_acc=0.9533
# Epoch  37 | train loss=0.6233 tok_acc=0.9615 | val loss=0.6484 tok_acc=0.9570
# Epoch  38 | train loss=0.6064 tok_acc=0.9627 | val loss=0.6371 tok_acc=0.9549
# Epoch  39 | train loss=0.5915 tok_acc=0.9638 | val loss=0.6276 tok_acc=0.9551
# Epoch  40 | train loss=0.5770 tok_acc=0.9646 | val loss=0.6206 tok_acc=0.9559
# Epoch  41 | train loss=0.5637 tok_acc=0.9652 | val loss=0.5902 tok_acc=0.9610
# Epoch  42 | train loss=0.5496 tok_acc=0.9661 | val loss=0.5751 tok_acc=0.9625
# Epoch  43 | train loss=0.5377 tok_acc=0.9672 | val loss=0.5587 tok_acc=0.9637
# Epoch  44 | train loss=0.5251 tok_acc=0.9680 | val loss=0.5494 tok_acc=0.9645
# Epoch  45 | train loss=0.5113 tok_acc=0.9690 | val loss=0.5397 tok_acc=0.9640
# Epoch  46 | train loss=0.5012 tok_acc=0.9693 | val loss=0.5466 tok_acc=0.9623
# Epoch  47 | train loss=0.4891 tok_acc=0.9700 | val loss=0.5297 tok_acc=0.9610
# Epoch  48 | train loss=0.4781 tok_acc=0.9709 | val loss=0.5093 tok_acc=0.9655
# Epoch  49 | train loss=0.4664 tok_acc=0.9714 | val loss=0.5049 tok_acc=0.9659
# Training complete. Best val loss: 0.5049
# ======================================================================
# Training Shortest Path 14L + Aux (lambda=10.0)
# ======================================================================
# Device: cuda
# Vocab size: 127
# Model parameters: 2,808,704
# Probe parameters: 134,640
# Using 2 GPUs with DataParallel
# Epoch   0 | train loss=37.4383 tok_acc=0.2982 | val loss=30.2797 tok_acc=0.3614
# Epoch   1 | train loss=28.6352 tok_acc=0.4373 | val loss=27.3398 tok_acc=0.4636
# Epoch   2 | train loss=26.1878 tok_acc=0.4726 | val loss=25.0996 tok_acc=0.4792
# Epoch   3 | train loss=24.0557 tok_acc=0.4875 | val loss=23.0672 tok_acc=0.4912
# Epoch   4 | train loss=22.0952 tok_acc=0.4970 | val loss=21.1467 tok_acc=0.4980
# Epoch   5 | train loss=19.9954 tok_acc=0.5255 | val loss=18.8558 tok_acc=0.5481
# Epoch   6 | train loss=17.7885 tok_acc=0.5870 | val loss=16.9144 tok_acc=0.6070
# Epoch   7 | train loss=16.0376 tok_acc=0.6287 | val loss=15.3279 tok_acc=0.6517
# Epoch   8 | train loss=14.5086 tok_acc=0.6574 | val loss=13.9285 tok_acc=0.6677
# Epoch   9 | train loss=13.1846 tok_acc=0.6811 | val loss=12.6513 tok_acc=0.6829
# Epoch  10 | train loss=12.0397 tok_acc=0.7034 | val loss=11.6001 tok_acc=0.7146
# Epoch  11 | train loss=11.0488 tok_acc=0.7237 | val loss=10.6858 tok_acc=0.7349
# Epoch  12 | train loss=10.1901 tok_acc=0.7433 | val loss=9.8940 tok_acc=0.7498
# Epoch  13 | train loss=9.4118 tok_acc=0.7632 | val loss=9.1604 tok_acc=0.7665
# Epoch  14 | train loss=8.7336 tok_acc=0.7779 | val loss=8.5496 tok_acc=0.7794
# Epoch  15 | train loss=8.1522 tok_acc=0.7887 | val loss=8.0220 tok_acc=0.7905
# Epoch  16 | train loss=7.6580 tok_acc=0.7980 | val loss=7.5541 tok_acc=0.7937
# Epoch  17 | train loss=7.2129 tok_acc=0.8060 | val loss=7.2081 tok_acc=0.8034
# Epoch  18 | train loss=6.8327 tok_acc=0.8142 | val loss=6.8420 tok_acc=0.8089
# Epoch  19 | train loss=6.5054 tok_acc=0.8211 | val loss=6.5431 tok_acc=0.8174
# Epoch  20 | train loss=6.2115 tok_acc=0.8264 | val loss=6.2581 tok_acc=0.8205
# Epoch  21 | train loss=5.9368 tok_acc=0.8318 | val loss=6.0003 tok_acc=0.8275
# Epoch  22 | train loss=5.6997 tok_acc=0.8366 | val loss=5.8206 tok_acc=0.8328
# Epoch  23 | train loss=5.4744 tok_acc=0.8401 | val loss=5.5856 tok_acc=0.8331
# Epoch  24 | train loss=5.2710 tok_acc=0.8445 | val loss=5.3962 tok_acc=0.8386
# Epoch  25 | train loss=5.0806 tok_acc=0.8473 | val loss=5.2412 tok_acc=0.8400
# Epoch  26 | train loss=4.9078 tok_acc=0.8508 | val loss=5.1112 tok_acc=0.8426
# Epoch  27 | train loss=4.7454 tok_acc=0.8538 | val loss=4.8645 tok_acc=0.8500
# Epoch  28 | train loss=4.6011 tok_acc=0.8571 | val loss=4.7760 tok_acc=0.8500
# Epoch  29 | train loss=4.4585 tok_acc=0.8592 | val loss=4.6416 tok_acc=0.8547
# Epoch  30 | train loss=4.3242 tok_acc=0.8617 | val loss=4.5709 tok_acc=0.8492
# Epoch  31 | train loss=4.2020 tok_acc=0.8641 | val loss=4.4208 tok_acc=0.8528
# Epoch  32 | train loss=4.0822 tok_acc=0.8663 | val loss=4.2849 tok_acc=0.8565
# Epoch  33 | train loss=3.9698 tok_acc=0.8685 | val loss=4.2071 tok_acc=0.8623
# Epoch  34 | train loss=3.8659 tok_acc=0.8707 | val loss=4.0899 tok_acc=0.8610
# Epoch  35 | train loss=3.7678 tok_acc=0.8724 | val loss=4.0120 tok_acc=0.8605
# Epoch  36 | train loss=3.6796 tok_acc=0.8744 | val loss=3.9408 tok_acc=0.8648
# Epoch  37 | train loss=3.5883 tok_acc=0.8771 | val loss=3.8001 tok_acc=0.8676
# Epoch  38 | train loss=3.5065 tok_acc=0.8784 | val loss=3.8123 tok_acc=0.8644
# Epoch  39 | train loss=3.4283 tok_acc=0.8800 | val loss=3.6742 tok_acc=0.8770
# Epoch  40 | train loss=3.3566 tok_acc=0.8813 | val loss=3.7044 tok_acc=0.8556
# Epoch  41 | train loss=3.2837 tok_acc=0.8827 | val loss=3.5419 tok_acc=0.8761
# Epoch  42 | train loss=3.2181 tok_acc=0.8845 | val loss=3.5078 tok_acc=0.8756
# Epoch  43 | train loss=3.1566 tok_acc=0.8862 | val loss=3.4732 tok_acc=0.8783
# Epoch  44 | train loss=3.0937 tok_acc=0.8873 | val loss=3.4142 tok_acc=0.8786
# Epoch  45 | train loss=3.0275 tok_acc=0.8887 | val loss=3.3430 tok_acc=0.8786
# Epoch  46 | train loss=2.9794 tok_acc=0.8903 | val loss=3.2817 tok_acc=0.8842
# Epoch  47 | train loss=2.9237 tok_acc=0.8912 | val loss=3.2942 tok_acc=0.8791
# Epoch  48 | train loss=2.8719 tok_acc=0.8923 | val loss=3.2435 tok_acc=0.8782
# Epoch  49 | train loss=2.8280 tok_acc=0.8935 | val loss=3.1628 tok_acc=0.8874
# Training complete. Best val loss: 3.1628

# %% [markdown]
# ## 5. Продолжение обучения с чекпоинта
#
# В каждом `SAVE_DIR` хранится только один лучший чекпоинт: `checkpoint_best.pt`. При новом улучшении он перезаписывается, поэтому на Kaggle не копятся десятки моделей.

# %%
# # Продолжить SFT 2L:
# n_layer = 2
# SAVE_DIR = CKPT_DIR / f"dijkstra_sft_{n_layer}L"
# RESUME_FROM = SAVE_DIR / "checkpoint_best.pt"
# EPOCHS = 80
# !"$PYTHON" -m shortest_path_dijkstra.src.train \\
#     --train_path "{DATA_DIR / 'train.json'}" \\
#     --val_path "{DATA_DIR / 'val.json'}" \\
#     --graph_n {GRAPH_N} \\
#     --max_weight {MAX_WEIGHT} \\
#     --max_distance {MAX_DISTANCE} \\
#     --d_model {D_MODEL} --n_layer {n_layer} --n_head {N_HEAD} \\
#     --max_seq_len {MAX_SEQ_LEN} \\
#     --lr {LR} --weight_decay 0.01 \\
#     --batch_size {BATCH_SIZE} --epochs {EPOCHS} --patience {PATIENCE} \\
#     --lambda_state 0.0 \\
#     --num_workers 2 \\
#     --save_dir "{SAVE_DIR}" \\
#     --resume_from "{RESUME_FROM}" \\
#     --seed 42

# # Продолжить 2L + auxiliary loss:
# aux_lambda = 1.0
# SAVE_DIR = CKPT_DIR / f"dijkstra_aux_2L_lambda{aux_lambda}"
# RESUME_FROM = SAVE_DIR / "checkpoint_best.pt"
# EPOCHS = 80
# !"$PYTHON" -m shortest_path_dijkstra.src.train \\
#     --train_path "{DATA_DIR / 'train.json'}" \\
#     --val_path "{DATA_DIR / 'val.json'}" \\
#     --graph_n {GRAPH_N} \\
#     --max_weight {MAX_WEIGHT} \\
#     --max_distance {MAX_DISTANCE} \\
#     --d_model {D_MODEL} --n_layer 2 --n_head {N_HEAD} \\
#     --max_seq_len {MAX_SEQ_LEN} \\
#     --lr {LR} --weight_decay 0.01 \\
#     --batch_size {BATCH_SIZE} --epochs {EPOCHS} --patience {PATIENCE} \\
#     --lambda_state {aux_lambda} \\
#     --num_workers 2 \\
#     --save_dir "{SAVE_DIR}" \\
#     --resume_from "{RESUME_FROM}" \\
#     --seed 42

# %% [markdown]
# ## 6. Evaluation

# %%
from shortest_path_dijkstra.src.evaluate import evaluate_all

all_eval = {}

for n_layer in SFT_LAYERS:
    name = f"SFT {n_layer}L"
    print(f"\n{'=' * 70}")
    print(name)
    print(f"{'=' * 70}")
    all_eval[name] = evaluate_all(
        checkpoint_path=str(CKPT_DIR / f"dijkstra_sft_{n_layer}L" / "checkpoint_best.pt"),
        data_dir=str(DATA_DIR),
        batch_size=BATCH_SIZE,
        lambda_state=0.0,
        graph_n=GRAPH_N,
        max_weight=MAX_WEIGHT,
        max_distance=MAX_DISTANCE,
        d_model=D_MODEL,
        n_layer=n_layer,
        n_head=N_HEAD,
        max_seq_len=MAX_SEQ_LEN,
    )

for n_layer in AUX_LAYERS:
    for aux_lambda in AUX_LAMBDAS:
        name = f"{n_layer}L + Aux (lambda={aux_lambda})"
        print(f"\n{'=' * 70}")
        print(name)
        print(f"{'=' * 70}")
        all_eval[name] = evaluate_all(
            checkpoint_path=str(CKPT_DIR / f"dijkstra_aux_{n_layer}L_lambda{aux_lambda}" / "checkpoint_best.pt"),
            data_dir=str(DATA_DIR),
            batch_size=BATCH_SIZE,
            lambda_state=aux_lambda,
            graph_n=GRAPH_N,
            max_weight=MAX_WEIGHT,
            max_distance=MAX_DISTANCE,
            d_model=D_MODEL,
            n_layer=n_layer,
            n_head=N_HEAD,
            max_seq_len=MAX_SEQ_LEN,
        )
# Out:
# ======================================================================
# SFT 10L
# ======================================================================
# test_id: exact_match=0.7530 distance_acc=0.9600 token_acc=0.9655 ntp_loss=0.1044 state_loss=0.0000 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0740 distance_acc=0.7187 token_acc=0.7521 ntp_loss=1.0019 state_loss=0.0000 (n=2000)
# test_ood_dense: exact_match=0.8920 distance_acc=0.9872 token_acc=0.9885 ntp_loss=0.0377 state_loss=0.0000 (n=2000)
# test_ood_equal_ties: exact_match=0.9995 distance_acc=1.0000 token_acc=1.0000 ntp_loss=0.0002 state_loss=0.0000 (n=2000)
# test_ood_layered_bipartite: exact_match=0.9845 distance_acc=0.9984 token_acc=0.9986 ntp_loss=0.0063 state_loss=0.0000 (n=2000)
# test_ood_long_chain: exact_match=0.2130 distance_acc=0.7957 token_acc=0.8370 ntp_loss=0.5242 state_loss=0.0000 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0305 distance_acc=0.7167 token_acc=0.7507 ntp_loss=1.2229 state_loss=0.0000 (n=2000)
#
# ======================================================================
# SFT 14L
# ======================================================================
# test_id: exact_match=0.7540 distance_acc=0.9608 token_acc=0.9647 ntp_loss=0.1070 state_loss=0.0000 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0735 distance_acc=0.7255 token_acc=0.7539 ntp_loss=0.6942 state_loss=0.0000 (n=2000)
# test_ood_dense: exact_match=0.8100 distance_acc=0.9761 token_acc=0.9781 ntp_loss=0.0729 state_loss=0.0000 (n=2000)
# test_ood_equal_ties: exact_match=0.9830 distance_acc=0.9983 token_acc=0.9985 ntp_loss=0.0074 state_loss=0.0000 (n=2000)
# test_ood_layered_bipartite: exact_match=0.9880 distance_acc=0.9988 token_acc=0.9989 ntp_loss=0.0092 state_loss=0.0000 (n=2000)
# test_ood_long_chain: exact_match=0.1830 distance_acc=0.7765 token_acc=0.8010 ntp_loss=0.5979 state_loss=0.0000 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0000 distance_acc=0.4925 token_acc=0.5386 ntp_loss=3.0292 state_loss=0.0000 (n=2000)
#
# ======================================================================
# 10L + Aux (lambda=0.1)
# ======================================================================
# test_id: exact_match=0.6565 distance_acc=0.9429 token_acc=0.9490 ntp_loss=0.1462 state_loss=1.1693 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0390 distance_acc=0.6844 token_acc=0.7202 ntp_loss=0.9459 state_loss=1.3662 (n=2000)
# test_ood_dense: exact_match=0.7830 distance_acc=0.9716 token_acc=0.9746 ntp_loss=0.0800 state_loss=1.0329 (n=2000)
# test_ood_equal_ties: exact_match=0.9710 distance_acc=0.9970 token_acc=0.9972 ntp_loss=0.0089 state_loss=0.7049 (n=2000)
# test_ood_layered_bipartite: exact_match=0.9625 distance_acc=0.9962 token_acc=0.9965 ntp_loss=0.0167 state_loss=1.0138 (n=2000)
# test_ood_long_chain: exact_match=0.1575 distance_acc=0.7491 token_acc=0.7816 ntp_loss=0.6717 state_loss=1.3670 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0015 distance_acc=0.6068 token_acc=0.6480 ntp_loss=1.1743 state_loss=1.9539 (n=2000)
#
# ======================================================================
# 10L + Aux (lambda=1.0)
# ======================================================================
# test_id: exact_match=0.6555 distance_acc=0.9414 token_acc=0.9503 ntp_loss=0.1347 state_loss=0.4042 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0305 distance_acc=0.6370 token_acc=0.7400 ntp_loss=0.9199 state_loss=0.8084 (n=2000)
# test_ood_dense: exact_match=0.8490 distance_acc=0.9807 token_acc=0.9830 ntp_loss=0.0473 state_loss=0.2897 (n=2000)
# test_ood_equal_ties: exact_match=0.9995 distance_acc=1.0000 token_acc=1.0000 ntp_loss=0.0004 state_loss=0.1991 (n=2000)
# test_ood_layered_bipartite: exact_match=0.9720 distance_acc=0.9972 token_acc=0.9975 ntp_loss=0.0079 state_loss=0.1866 (n=2000)
# test_ood_long_chain: exact_match=0.2050 distance_acc=0.7820 token_acc=0.8620 ntp_loss=0.4026 state_loss=0.6121 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0170 distance_acc=0.6592 token_acc=0.7231 ntp_loss=0.8746 state_loss=1.0627 (n=2000)
#
# ======================================================================
# 10L + Aux (lambda=10.0)
# ======================================================================
# test_id: exact_match=0.2440 distance_acc=0.8391 token_acc=0.8607 ntp_loss=0.3634 state_loss=0.3267 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0165 distance_acc=0.6515 token_acc=0.7340 ntp_loss=0.6590 state_loss=0.4689 (n=2000)
# test_ood_dense: exact_match=0.4730 distance_acc=0.9238 token_acc=0.9332 ntp_loss=0.1700 state_loss=0.2510 (n=2000)
# test_ood_equal_ties: exact_match=0.8970 distance_acc=0.9895 token_acc=0.9903 ntp_loss=0.0264 state_loss=0.2640 (n=2000)
# test_ood_layered_bipartite: exact_match=0.6950 distance_acc=0.9664 token_acc=0.9692 ntp_loss=0.0923 state_loss=0.1817 (n=2000)
# test_ood_long_chain: exact_match=0.0120 distance_acc=0.5961 token_acc=0.6745 ntp_loss=0.8634 state_loss=0.4435 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0030 distance_acc=0.5959 token_acc=0.6746 ntp_loss=0.9565 state_loss=0.8022 (n=2000)
#
# ======================================================================
# 14L + Aux (lambda=0.1)
# ======================================================================
# test_id: exact_match=0.7215 distance_acc=0.9559 token_acc=0.9610 ntp_loss=0.1061 state_loss=0.9812 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0840 distance_acc=0.7431 token_acc=0.7827 ntp_loss=0.7232 state_loss=1.2448 (n=2000)
# test_ood_dense: exact_match=0.8770 distance_acc=0.9852 token_acc=0.9869 ntp_loss=0.0390 state_loss=0.8374 (n=2000)
# test_ood_equal_ties: exact_match=0.9975 distance_acc=0.9998 token_acc=0.9998 ntp_loss=0.0009 state_loss=0.6734 (n=2000)
# test_ood_layered_bipartite: exact_match=0.9800 distance_acc=0.9980 token_acc=0.9982 ntp_loss=0.0062 state_loss=0.7755 (n=2000)
# test_ood_long_chain: exact_match=0.2110 distance_acc=0.7869 token_acc=0.8183 ntp_loss=0.5393 state_loss=1.2532 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0360 distance_acc=0.7368 token_acc=0.7678 ntp_loss=0.8820 state_loss=1.5146 (n=2000)
#
# ======================================================================
# 14L + Aux (lambda=1.0)
# ======================================================================
# test_id: exact_match=0.7265 distance_acc=0.9574 token_acc=0.9625 ntp_loss=0.1043 state_loss=0.4146 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0300 distance_acc=0.6432 token_acc=0.7147 ntp_loss=1.0440 state_loss=0.7050 (n=2000)
# test_ood_dense: exact_match=0.8900 distance_acc=0.9862 token_acc=0.9877 ntp_loss=0.0405 state_loss=0.3254 (n=2000)
# test_ood_equal_ties: exact_match=0.9230 distance_acc=0.9919 token_acc=0.9926 ntp_loss=0.0255 state_loss=0.2431 (n=2000)
# test_ood_layered_bipartite: exact_match=0.9720 distance_acc=0.9972 token_acc=0.9974 ntp_loss=0.0089 state_loss=0.2470 (n=2000)
# test_ood_long_chain: exact_match=0.1890 distance_acc=0.7805 token_acc=0.8293 ntp_loss=0.5032 state_loss=0.5306 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0315 distance_acc=0.6551 token_acc=0.7007 ntp_loss=1.0025 state_loss=1.1626 (n=2000)
#
# ======================================================================
# 14L + Aux (lambda=10.0)
# ======================================================================
# test_id: exact_match=0.3165 distance_acc=0.8669 token_acc=0.8819 ntp_loss=0.3123 state_loss=0.2895 (n=2000)
# test_ood_adversarial_direct: exact_match=0.0055 distance_acc=0.5833 token_acc=0.6672 ntp_loss=0.9854 state_loss=0.5629 (n=2000)
# test_ood_dense: exact_match=0.6320 distance_acc=0.9499 token_acc=0.9552 ntp_loss=0.1222 state_loss=0.2140 (n=2000)
# test_ood_equal_ties: exact_match=0.9390 distance_acc=0.9936 token_acc=0.9941 ntp_loss=0.0179 state_loss=0.1683 (n=2000)
# test_ood_layered_bipartite: exact_match=0.8165 distance_acc=0.9805 token_acc=0.9822 ntp_loss=0.0534 state_loss=0.1249 (n=2000)
# test_ood_long_chain: exact_match=0.0155 distance_acc=0.6300 token_acc=0.6858 ntp_loss=0.9091 state_loss=0.6110 (n=2000)
# test_ood_near_complete_hidden_path: exact_match=0.0035 distance_acc=0.6319 token_acc=0.6840 ntp_loss=1.1099 state_loss=1.2394 (n=2000)

# %%
import pandas as pd

pd.set_option("display.max_rows", 100)

rows = []
for model_name, result in all_eval.items():
    for split, metrics in result.items():
        rows.append({
            "model": model_name,
            "split": split,
            "exact_match": metrics["exact_match"],
            "distance_accuracy": metrics["distance_accuracy"],
            "token_accuracy": metrics["token_accuracy"],
            "ntp_loss": metrics["loss_main"],
            "total_loss": metrics["loss"],
            "loss_state": metrics["loss_state"],
        })
df = pd.DataFrame(rows)
df
# Out:
#                       model                               split  exact_match  \
# 0                   SFT 10L                             test_id       0.7530
# 1                   SFT 10L         test_ood_adversarial_direct       0.0740
# 2                   SFT 10L                      test_ood_dense       0.8920
# 3                   SFT 10L                 test_ood_equal_ties       0.9995
# 4                   SFT 10L          test_ood_layered_bipartite       0.9845
# 5                   SFT 10L                 test_ood_long_chain       0.2130
# 6                   SFT 10L  test_ood_near_complete_hidden_path       0.0305
# 7                   SFT 14L                             test_id       0.7540
# 8                   SFT 14L         test_ood_adversarial_direct       0.0735
# 9                   SFT 14L                      test_ood_dense       0.8100
# 10                  SFT 14L                 test_ood_equal_ties       0.9830
# 11                  SFT 14L          test_ood_layered_bipartite       0.9880
# 12                  SFT 14L                 test_ood_long_chain       0.1830
# 13                  SFT 14L  test_ood_near_complete_hidden_path       0.0000
# 14   10L + Aux (lambda=0.1)                             test_id       0.6565
# 15   10L + Aux (lambda=0.1)         test_ood_adversarial_direct       0.0390
# 16   10L + Aux (lambda=0.1)                      test_ood_dense       0.7830
# 17   10L + Aux (lambda=0.1)                 test_ood_equal_ties       0.9710
# 18   10L + Aux (lambda=0.1)          test_ood_layered_bipartite       0.9625
# 19   10L + Aux (lambda=0.1)                 test_ood_long_chain       0.1575
# 20   10L + Aux (lambda=0.1)  test_ood_near_complete_hidden_path       0.0015
# 21   10L + Aux (lambda=1.0)                             test_id       0.6555
# 22   10L + Aux (lambda=1.0)         test_ood_adversarial_direct       0.0305
# 23   10L + Aux (lambda=1.0)                      test_ood_dense       0.8490
# 24   10L + Aux (lambda=1.0)                 test_ood_equal_ties       0.9995
# 25   10L + Aux (lambda=1.0)          test_ood_layered_bipartite       0.9720
# 26   10L + Aux (lambda=1.0)                 test_ood_long_chain       0.2050
# 27   10L + Aux (lambda=1.0)  test_ood_near_complete_hidden_path       0.0170
# 28  10L + Aux (lambda=10.0)                             test_id       0.2440
# 29  10L + Aux (lambda=10.0)         test_ood_adversarial_direct       0.0165
# 30  10L + Aux (lambda=10.0)                      test_ood_dense       0.4730
# 31  10L + Aux (lambda=10.0)                 test_ood_equal_ties       0.8970
# 32  10L + Aux (lambda=10.0)          test_ood_layered_bipartite       0.6950
# 33  10L + Aux (lambda=10.0)                 test_ood_long_chain       0.0120
# 34  10L + Aux (lambda=10.0)  test_ood_near_complete_hidden_path       0.0030
# 35   14L + Aux (lambda=0.1)                             test_id       0.7215
# 36   14L + Aux (lambda=0.1)         test_ood_adversarial_direct       0.0840
# 37   14L + Aux (lambda=0.1)                      test_ood_dense       0.8770
# 38   14L + Aux (lambda=0.1)                 test_ood_equal_ties       0.9975
# 39   14L + Aux (lambda=0.1)          test_ood_layered_bipartite       0.9800
# 40   14L + Aux (lambda=0.1)                 test_ood_long_chain       0.2110
# 41   14L + Aux (lambda=0.1)  test_ood_near_complete_hidden_path       0.0360
# 42   14L + Aux (lambda=1.0)                             test_id       0.7265
# 43   14L + Aux (lambda=1.0)         test_ood_adversarial_direct       0.0300
# 44   14L + Aux (lambda=1.0)                      test_ood_dense       0.8900
# 45   14L + Aux (lambda=1.0)                 test_ood_equal_ties       0.9230
# 46   14L + Aux (lambda=1.0)          test_ood_layered_bipartite       0.9720
# 47   14L + Aux (lambda=1.0)                 test_ood_long_chain       0.1890
# 48   14L + Aux (lambda=1.0)  test_ood_near_complete_hidden_path       0.0315
# 49  14L + Aux (lambda=10.0)                             test_id       0.3165
# 50  14L + Aux (lambda=10.0)         test_ood_adversarial_direct       0.0055
# 51  14L + Aux (lambda=10.0)                      test_ood_dense       0.6320
# 52  14L + Aux (lambda=10.0)                 test_ood_equal_ties       0.9390
# 53  14L + Aux (lambda=10.0)          test_ood_layered_bipartite       0.8165
# 54  14L + Aux (lambda=10.0)                 test_ood_long_chain       0.0155
# 55  14L + Aux (lambda=10.0)  test_ood_near_complete_hidden_path       0.0035
#
#     distance_accuracy  token_accuracy  ntp_loss  total_loss  loss_state
# 0             0.96005        0.965500  0.104389    0.104389    0.000000
# 1             0.71865        0.752091  1.001896    1.001896    0.000000
# 2             0.98725        0.988545  0.037737    0.037737    0.000000
# 3             0.99995        0.999955  0.000243    0.000243    0.000000
# 4             0.99845        0.998591  0.006310    0.006310    0.000000
# 5             0.79575        0.837045  0.524169    0.524169    0.000000
# 6             0.71670        0.750682  1.222919    1.222919    0.000000
# 7             0.96080        0.964727  0.106997    0.106997    0.000000
# 8             0.72545        0.753864  0.694241    0.694241    0.000000
# 9             0.97615        0.978091  0.072946    0.072946    0.000000
# 10            0.99830        0.998455  0.007391    0.007391    0.000000
# 11            0.99880        0.998909  0.009182    0.009182    0.000000
# 12            0.77650        0.801045  0.597947    0.597947    0.000000
# 13            0.49250        0.538591  3.029229    3.029229    0.000000
# 14            0.94290        0.949000  0.146176    0.263105    1.169288
# 15            0.68435        0.720227  0.945851    1.082470    1.366191
# 16            0.97160        0.974636  0.080010    0.183302    1.032928
# 17            0.99695        0.997227  0.008923    0.079412    0.704897
# 18            0.99625        0.996545  0.016720    0.118100    1.013791
# 19            0.74915        0.781591  0.671720    0.808423    1.367033
# 20            0.60675        0.648000  1.174265    1.369651    1.953864
# 21            0.94140        0.950318  0.134727    0.538894    0.404167
# 22            0.63700        0.740045  0.919931    1.728290    0.808359
# 23            0.98070        0.983000  0.047258    0.336931    0.289673
# 24            0.99995        0.999955  0.000400    0.199485    0.199086
# 25            0.99720        0.997455  0.007887    0.194516    0.186629
# 26            0.78200        0.862045  0.402609    1.014727    0.612118
# 27            0.65915        0.723136  0.874561    1.937230    1.062670
# 28            0.83915        0.860727  0.363414    3.629955    0.326654
# 29            0.65150        0.734000  0.658994    5.347783    0.468879
# 30            0.92380        0.933182  0.170033    2.680186    0.251015
# 31            0.98945        0.990318  0.026401    2.666554    0.264015
# 32            0.96635        0.969227  0.092298    1.909355    0.181706
# 33            0.59610        0.674500  0.863421    5.298462    0.443504
# 34            0.59595        0.674636  0.956504    8.978319    0.802181
# 35            0.95590        0.960955  0.106101    0.204225    0.981243
# 36            0.74310        0.782682  0.723162    0.847645    1.244825
# 37            0.98525        0.986864  0.038980    0.122717    0.837369
# 38            0.99975        0.999773  0.000939    0.068283    0.673441
# 39            0.99800        0.998182  0.006211    0.083766    0.775548
# 40            0.78685        0.818273  0.539293    0.664610    1.253163
# 41            0.73680        0.767773  0.881967    1.033431    1.514639
# 42            0.95735        0.962545  0.104308    0.518904    0.414596
# 43            0.64325        0.714727  1.044036    1.749016    0.704980
# 44            0.98620        0.987727  0.040537    0.365947    0.325410
# 45            0.99185        0.992591  0.025517    0.268616    0.243099
# 46            0.99720        0.997409  0.008896    0.255902    0.247006
# 47            0.78050        0.829318  0.503224    1.033777    0.530553
# 48            0.65505        0.700727  1.002463    2.165103    1.162640
# 49            0.86685        0.881909  0.312300    3.206935    0.289463
# 50            0.58330        0.667227  0.985448    6.614086    0.562864
# 51            0.94995        0.955227  0.122222    2.262387    0.214016
# 52            0.99355        0.994136  0.017924    1.700880    0.168296
# 53            0.98045        0.982182  0.053385    1.302076    0.124869
# 54            0.63000        0.685818  0.909137    7.019108    0.610997
# 55            0.63190        0.683955  1.109914   13.503431    1.239352

# %% [markdown]
# ## 7. Training curves

# %%
import matplotlib.pyplot as plt

def load_log(path):
    with open(path) as f:
        return json.load(f)

logs = {
    **{
        f"SFT {n_layer}L": load_log(CKPT_DIR / f"dijkstra_sft_{n_layer}L" / "train_log.json")
        for n_layer in SFT_LAYERS
    },
    **{
        f"{n_layer}L + Aux ({aux_lambda})": load_log(
            CKPT_DIR / f"dijkstra_aux_{n_layer}L_lambda{aux_lambda}" / "train_log.json"
        )
        for n_layer in AUX_LAYERS
        for aux_lambda in AUX_LAMBDAS
    },
}

fig, axes = plt.subplots(1, 3, figsize=(15, 4))
for label, log in logs.items():
    epochs = [row["epoch"] for row in log]
    axes[0].plot(epochs, [row["val"]["loss_main"] for row in log], label=label)
    axes[1].plot(epochs, [row["val"]["token_accuracy"] for row in log], label=label)
    if any(row["val"]["loss_state"] > 0 for row in log):
        axes[2].plot(epochs, [row["val"]["loss_state"] for row in log], label=label)

axes[0].set_title("Val NTP loss")
axes[1].set_title("Val token accuracy")
axes[1].set_ylim(0.0, 1.02)
axes[2].set_title("Val Dijkstra-state loss")
for ax in axes:
    ax.grid(True, alpha=0.3)
    ax.legend()
plt.tight_layout()

# %% [markdown]
# ## 8. Split Heatmaps
#
# Сразу две защитные картинки: exact match и distance-wise accuracy на всех fixed-size split'ах.

# %%
import seaborn as sns
import numpy as np

split_order = [
    "test_id",
    "test_ood_dense",
    "test_ood_long_chain",
    "test_ood_adversarial_direct",
    "test_ood_equal_ties",
    "test_ood_layered_bipartite",
    "test_ood_near_complete_hidden_path",
]
split_labels = {
    "test_id": "ID",
    "test_ood_dense": "Dense",
    "test_ood_long_chain": "Long chain",
    "test_ood_adversarial_direct": "Adv. direct",
    "test_ood_equal_ties": "Equal ties",
    "test_ood_layered_bipartite": "Layered bipartite",
    "test_ood_near_complete_hidden_path": "Hidden path",
}

exact_df = pd.DataFrame(
    {
        model_name: {
            split_labels[split]: all_eval[model_name][split]["exact_match"]
            for split in split_order
            if split in all_eval[model_name]
        }
        for model_name in all_eval
    }
).T
distance_df = pd.DataFrame(
    {
        model_name: {
            split_labels[split]: all_eval[model_name][split]["distance_accuracy"]
            for split in split_order
            if split in all_eval[model_name]
        }
        for model_name in all_eval
    }
).T

fig, axes = plt.subplots(1, 2, figsize=(18, 6))
sns.heatmap(exact_df, annot=True, fmt=".3f", cmap="YlGnBu", vmin=0.0, vmax=1.0, ax=axes[0])
axes[0].set_title("Exact match by model and split")
axes[0].set_xlabel("Split")
axes[0].set_ylabel("Model")

sns.heatmap(distance_df, annot=True, fmt=".3f", cmap="YlOrBr", vmin=0.0, vmax=1.0, ax=axes[1])
axes[1].set_title("Distance-wise accuracy by model and split")
axes[1].set_xlabel("Split")
axes[1].set_ylabel("Model")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. OOD Gap Relative to ID
#
# Эти графики удобны, когда хочется показать не только абсолютное качество, но и устойчивость модели при сдвиге распределения.

# %%
id_scores = exact_df["ID"]
drop_df = exact_df.apply(lambda col: id_scores - col)
ood_drop_df = drop_df[[col for col in exact_df.columns if col != "ID"]]

aux_candidates = [name for name in all_eval if " + Aux " in name]
best_aux_name = max(
    aux_candidates,
    key=lambda name: np.mean([all_eval[name][split]["exact_match"] for split in split_order if split != "test_id"]),
)

representative_models = []
for candidate in [f"SFT {SFT_LAYERS[0]}L", f"SFT {SFT_LAYERS[-1]}L", best_aux_name]:
    if candidate in all_eval and candidate not in representative_models:
        representative_models.append(candidate)

fig, axes = plt.subplots(1, 2, figsize=(18, 5))
sns.heatmap(ood_drop_df * 100, annot=True, fmt=".1f", cmap="Reds", vmin=0.0, ax=axes[0])
axes[0].set_title("Exact-match drop vs ID (percentage points)")
axes[0].set_xlabel("OOD split")
axes[0].set_ylabel("Model")

x = np.arange(len(split_order))
for model_name in representative_models:
    ys = [all_eval[model_name][split]["exact_match"] for split in split_order]
    axes[1].plot(x, ys, marker="o", linewidth=2, label=model_name)
axes[1].set_xticks(x)
axes[1].set_xticklabels([split_labels[split] for split in split_order], rotation=30, ha="right")
axes[1].set_ylim(0.0, 1.02)
axes[1].set_ylabel("Exact match")
axes[1].set_title("Representative model profiles across splits")
axes[1].grid(alpha=0.2)
axes[1].legend()

plt.tight_layout()
plt.show()
